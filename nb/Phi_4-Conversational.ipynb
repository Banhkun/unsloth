# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://docs.unsloth.ai/get-started/installing-+-updating).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save)

# %% [markdown]
# ### News

# %% [markdown]
# **Read our [blog post](https://unsloth.ai/blog/r1-reasoning) for guidance on how to train reasoning models.**
#
# Visit our docs for all our [model uploads](https://docs.unsloth.ai/get-started/all-our-models) and [notebooks](https://docs.unsloth.ai/get-started/unsloth-notebooks).

# %% [markdown]
# ### Installation

# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth
else:
    # Do this only in Colab and Kaggle notebooks! Otherwise use pip install unsloth
    # !pip install --no-deps bitsandbytes accelerate xformers==0.0.29 peft trl triton
    # !pip install --no-deps cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf datasets huggingface_hub hf_transfer
    # !pip install --no-deps unsloth

# %% [markdown]
# ### Unsloth

# %%
from unsloth import FastLanguageModel  # FastVisionModel for LLMs
import torch
max_seq_length = 2048  # Choose any! We auto support RoPE Scaling internally!
load_in_4bit = True  # Use 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/Meta-Llama-3.1-8B-bnb-4bit",  # Llama-3.1 2x faster
    "unsloth/Mistral-Small-Instruct-2409",  # Mistral 22b 2x faster!
    "unsloth/Phi-4",  # Phi-4 2x faster!
    "unsloth/Phi-4-unsloth-bnb-4bit",  # Phi-4 Unsloth Dynamic 4-bit Quant
    "unsloth/gemma-2-9b-bnb-4bit",  # Gemma 2x faster!
    "unsloth/Qwen2.5-7B-Instruct-bnb-4bit"  # Qwen 2.5 2x faster!
    "unsloth/Llama-3.2-1B-bnb-4bit",  # NEW! Llama 3.2 models
    "unsloth/Llama-3.2-1B-Instruct-bnb-4bit",
    "unsloth/Llama-3.2-3B-bnb-4bit",
    "unsloth/Llama-3.2-3B-Instruct-bnb-4bit",
]  # More models at https://docs.unsloth.ai/get-started/all-our-models

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Phi-4",
    max_seq_length = max_seq_length,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.2.15: Fast Llama patching. Transformers: 4.48.3.
#    \\   /|    GPU: Tesla T4. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json:   0%|          | 0.00/160k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.39G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/1.03G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/170 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/18.0k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.61M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/917k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.15M [00:00<?, ?B/s]

# %% [markdown]
# We now add LoRA adapters for parameter efficient finetuning - this allows us to only efficiently train 1% of all parameters.

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth 2025.2.15 patched 40 layers with 40 QKV layers, 40 O layers and 40 MLP layers.

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep
# We now use the `Phi-4` format for conversation style finetunes. We use [Maxime Labonne's FineTome-100k](https://huggingface.co/datasets/mlabonne/FineTome-100k) dataset in ShareGPT style. But we convert it to HuggingFace's normal multiturn format `("role", "content")` instead of `("from", "value")`/ Phi-4 renders multi turn conversations like below:
#
# ```
# <|im_start|>user<|im_sep|>Hello!<|im_end|>
# <|im_start|>assistant<|im_sep|>Hi! How can I help?<|im_end|>
# <|im_start|>user<|im_sep|>What is 2+2?<|im_end|>
# ```
#
# We use our `get_chat_template` function to get the correct chat template. We support `zephyr, chatml, mistral, llama, alpaca, vicuna, vicuna_old, phi3, phi4, llama3` and more.

# %%
import pandas as pd
df = pd.read_pickle("/content/whole_data_UC4.pkl")

# %%
import pyarrow as pa
import pandas as pd
# Convert from pandas to Arrow
table = pa.Table.from_pandas(df)

# %%
from datasets import Dataset
# Step 2: Convert the DataFrame to a Hugging Face Dataset
UC4_dataset = Dataset.from_pandas(df)

# Step 3: Display the Dataset
print(UC4_dataset)
# Out:
# Dataset({
#     features: ['web-scraper-order', 'web-scraper-start-url', 'page', 'TITLE', 'CONTENT', 'TITLE_MARKDOWN', 'CONTENT_MARKDOWN', 'combined_text', 'structure_data'],
#     num_rows: 2109
# })

# %%
UC4_dataset[:5]["structure_data"]
# Out:
# [{'author': 'Friedmann Marcel (BD/DPA-CAL3)',
#   'content': '1. [Pages](https://inside-docupedia.bosch.com/confluence/collector/pages.action?key=GWA&src=breadcrumbs-collector)\n2. [Home](https://inside-docupedia.bosch.com/confluence/display/GWA/Home?src=breadcrumbs-parent)\n\n# [Customers and Users Area](https://inside-docupedia.bosch.com/confluence/display/GWA/Customers+and+Users+Area)\n\n* Created by  [Friedmann Marcel (BD/DPA-CAL3)](https://inside-docupedia.bosch.com/confluence/display/~FRM8BUE), last modified by  [Souliotis Marcos (BD/DPA-CAL1)](https://inside-docupedia.bosch.com/confluence/display/~OSM5FE) on [2018, Nov 19](https://inside-docupedia.bosch.com/confluence/pages/diffpagesbyversion.action?pageId=462389207&selectedPageVersions=37&selectedPageVersions=38 "Show changes")\n  \n  Current Version V 38\n[Page Info](# "Space Info")',
#   'created_date': '2018, Nov 19',
#   'features': ['Created by  [Friedmann Marcel (BD/DPA-CAL3)](https://inside-docupedia.bosch.com/confluence/display/~FRM8BUE), last modified by  [Souliotis Marcos (BD/DPA-CAL1)](https://inside-docupedia.bosch.com/confluence/display/~OSM5FE) on [2018, Nov 19](https://inside-docupedia.bosch.com/confluence/pages/diffpagesbyversion.action?pageId=462389207&selectedPageVersions=37&selectedPageVersions=38 "Show changes")'],
#   'links': {'![': None,
#    '![Home': None,
#    '![Users profile picture': None,
#    '"BAT"': None,
#    '"Declaration of Obligation for Administrators"': None,
#    '"EISA"': None,
#    '"Hierarchy View"': None,
#    '"Provision a new S3 bucket"': None,
#    '"Sending mails using the E-Mail task"': None,
#    '#1636': None,
#    '#1992': None,
#    '#1996': None,
#    '#2.2 SAML / OpenID Connect (OIDC)\xa0Authentication': None,
#    '#2080': None,
#    '#2336': None,
#    '#2374': None,
#    '#2412': None,
#    '#2432': None,
#    '#2505': None,
#    '#Request Status': None,
#    "'0' byte files": None,
#    '(Backup link)': None,
#    '(Haken)': None,
#    '(L2)': None,
#    '(Logon like on EUP4).': None,
#    '(NEU) Statistics of jobs': None,
#    '(O1)': None,
#    '(O3)': None,
#    '(O5)': None,
#    '(Recommended Learning Videos in CI Steering Enabling & Knowledge Hub': None,
#    '(S) How to get access to Splunk Data (via oneIDM)': None,
#    '(Verpflichtungserklärung)': None,
#    '(blue star)': None,
#    '(error)': None,
#    '(grey lightbulb)': None,
#    '(info)': None,
#    '(lightbulb)': None,
#    '(minus)': None,
#    '(plus)': None,
#    '(rbsg) File Share Migration': None,
#    '(red star)': None,
#    '(see separate description': None,
#    '(smile)': None,
#    '(spl02) Application Logging - splunk (ACTIVE)': None,
#    '(star)': None,
#    '(tick)': None,
#    '(warning)': None,
#    '(wink)': None,
#    ')': None,
#    '**ARMT**': None,
#    '**BD Interface Life Cycle Management**': None,
#    '**BD Quality Strategy** (2022)': None,
#    '**BD(CI) Quality Strategy**\xa0(2022)': None,
#    '**BoM+1 area:**': None,
#    '**Bosch Acronym Index**': None,
#    '**Bosch CERT - Dashboard**': None,
#    '**Bosch IDM**': None,
#    '**CD 02900 - ISP-CD Information Security and Data Protection**': None,
#    '**CD 07000 - Cyber Security Management System**': None,
#    '**CD 07900 - IT Security**': None,
#    '**CDQ 00907 - Complain Process**': None,
#    '**CI Steering**': None,
#    '**CI/PI - Risk Management**': None,
#    '**CI_ISA3 New global System Owner Concept 2018-04.pptx**': None,
#    '**Common Documents - IT Service Continuity Management O7**': None,
#    '**Docupedia**': None,
#    '**Draft: L4 - Deployment Management**': None,
#    '**Draft: O5 - Event Management**': None,
#    '**Draft: O9 - Availability Management**': None,
#    '**Draft: U3 - Continual Improvement**': None,
#    '**Eisenhut Helmut (CI/DAP51.3)**': None,
#    '**Enterprise Alert**': None,
#    '**Get Access**': None,
#    '**IDM LINK**': None,
#    '**IT P/S/S Excellence Process (IT PEP)**': None,
#    '**IT Service Portal (ITSP)**': None,
#    '**ITOM - Template Usage Guide**': None,
#    '**International**': None,
#    '**K3 - Charging**': None,
#    '**KMS Home**': None,
#    '**L2**': None,
#    '**L3 - Request Fulfillment**': None,
#    '**L3 -** **Standard Service Request criteria**': None,
#    '**L4**': None,
#    '**LeanIX definition**': None,
#    '**M3**': None,
#    '**M5 - Information Security Management**': None,
#    '**Necessary Tools**': None,
#    '**O1 - Incident Management**': None,
#    '**O2 - Problem Management**': None,
#    '**O3 - Change Management**': None,
#    '**O5**': None,
#    '**O6 - Configuration Manager**': None,
#    '**O7 - IT Service Continuity Management**': None,
#    '**O9**': None,
#    '**OneNote**': None,
#    '**Organization of Bosch Group**': None,
#    '**POA BGN Page**': None,
#    '**Planisware**': None,
#    '**RBGF 00104 - Risk Management System**': None,
#    '**RBGF 00105 - Information Security and Data Protection (ISP)**': None,
#    '**RBGF 00182 - Product Development Code**': None,
#    '**RUN**': None,
#    '**SMT - Service Management Toolsuite**': None,
#    '**SPoI - Single Point of Information**': None,
#    '**SUPPORT**': None,
#    '**SharePoint**': None,
#    '**Splunk**': None,
#    '**Start SMT-CMDB**': None,
#    '**T&R**:\xa0 OSATWO-1765': None,
#    '**U2 - Knowledge Management**': None,
#    '**U3 - Continual Improvement**': None,
#    '**U3**': None,
#    '**here**': None,
#    '**https://inside-docupedia.bosch.com/confluence/pages/viewpage.action?pageId=429723274**': None,
#    '**https://inside-docupedia.bosch.com/confluence/x/i1RZ1Q**': None,
#    '**https://rb-armt.bosch.com/jrm/**': None,
#    '**https://rb-smt.de.bosch.com**': None,
#    '**link**': None,
#    '**rb-eut1app1.server.bosch.com**': None,
#    '**this Link**': None,
#    '*BD/OS Process description*': None,
#    '*Continuity Management*': None,
#    '*fe0vmc2629.de.bosch.com*.': None,
#    '*oneIDM (bosch.com)*': None,
#    '.': None,
#    '/': None,
#    '/AEFRAMEWORK/': None,
#    '/Compas/': None,
#    '/EXTENSIONS/': None,
#    '/IDM/': None,
#    '/Supportutils/': None,
#    '/extensions/ae/<system>/healthStatus': None,
#    '/local/home/x0padm/.ssh/known_hosts': None,
#    '/objectExist?objectName=': None,
#    '0 Preamble': None,
#    '0 Preamble TODO': None,
#    '01 Introduction and Goals': None,
#    '01 Introduction and Goals#01IntroductionandGoals-1.1.4FunctionalRequirementsflw_high_lvl_req': None,
#    '01 Introduction and Goals#01IntroductionandGoals-1.2Stakeholders': None,
#    '01 Introduction and Goals#01IntroductionandGoals-1.3.1QualitycharacteristicsandNon-functionalRequirementsflw_non_func_req': None,
#    '01. Contacts': None,
#    '01016417': None,
#    '01159287': None,
#    '02 Constraints': None,
#    '02. Session Schedule': None,
#    '02. Sessions': None,
#    '03 System Scope and Context': None,
#    '04 Solution Strategy': None,
#    '05 Building Blocks': None,
#    '06 Runtime View': None,
#    '07 Deployment View': None,
#    '08 Crosscutting Concepts': None,
#    '09 Design Decisions': None,
#    '1': None,
#    '1 - Concept Zone': None,
#    '1 - Purpose': None,
#    '1 Service Design': None,
#    '1 Service Design AE': None,
#    '1- ARMT Request Process Description': None,
#    '1- Purpose': None,
#    '1. ARMT Request Process Description': None,
#    '1. Application Parameters': None,
#    '1. General Information_RUN Topic': None,
#    '1. Introduction Request Management tool': None,
#    '1. Members': None,
#    '1. Onboarding RUN Outsystems': None,
#    '1. Purpose': None,
#    '1. RASIC': None,
#    '1. Responsibility & Approval': None,
#    '1.1 How to request OutSystems role on oneIDM': None,
#    '1.1 Service Description': None,
#    '1.1 Service Description AE': None,
#    '1.1- Create Requests': None,
#    '1.1. Create Requests': None,
#    '1.2 Access to your OutSystems Application': None,
#    '1.2 General Overview About AWI': None,
#    '1.2 Service Level Management': None,
#    '1.2 Service Level Management AE': None,
#    '1.2- Update and Delete Requests': None,
#    '1.2. Update and Delete Requests': None,
#    '1.3 Risk Management': None,
#    '1.3 Risk Management TODO': None,
#    '1.3 Run Scope': None,
#    '1.3- Special and Complex Requests': None,
#    '1.3. Special and Complex Requests': None,
#    '1.4 Capacity Management': None,
#    '1.4 Capacity Management AE': None,
#    '1.4 Run Out Of Scope': None,
#    '1.5 Availability Management': None,
#    '1.5 Availability Management AE': None,
#    '1.5 Run Daily Activities': None,
#    '1.6 IT Service Continuity Management': None,
#    '1.6 IT Service Continuity Management AE': None,
#    '1.6 Tool Access list - Onboarding': None,
#    '1.6.1 Access to AEINFO APP': None,
#    '1.6.2 Access to Request Management(ARMT)': None,
#    '1.6.3 Access to ITOE Enterprise Alerting': None,
#    '1.6.4 Access to SPLUNK via OneIdm': None,
#    '1.7 Data Protection and Privacy': None,
#    '1.7 Data Protection and Privacy AE': None,
#    '1.8 Compliance Management': None,
#    '1.8 Compliance Management TODO': None,
#    '1.9 Cyber Security TODO': None,
#    '1.9 IT Security': None,
#    '1.Members_RUN': None,
#    '10 Quality': None,
#    '10-2019.pdf': None,
#    '10. Change History': None,
#    '10. Header Info': None,
#    '1055_Email Template.xlsx': None,
#    '11 Risks': None,
#    '11. Scheduled jobs in UC4': None,
#    '1113_Feedback.pptx': None,
#    '116': None,
#    '12 Glossary': None,
#    '12. Expiration Alerts': None,
#    '12.2': None,
#    '12.2.2_lizenzen.zip': None,
#    '12.3': None,
#    '121ARA_Service_Spec_Sheet_ARA_Service.pdf': None,
#    '121ARA_Service_Spec_Sheet_ARA_Service_V1.2.pdf': None,
#    '121FTP_Service_Spec_Sheet_SFTP_Data_Exchange.pdf': None,
#    '121FTP_Service_Spec_Sheet_SFTP_Data_Exchange_V1.7.pdf': None,
#    '121FTS_Service_Spec_Sheet_UC4_FileTransfer_V1.0.pdf': None,
#    '121UC4_Service_Spec_Sheet_UC4_Administration.pdf': None,
#    '121UC4_Service_Spec_Sheet_UC4_Administration_v3.2.pdf': None,
#    '121UCE_Service_Spec_Sheet_UC4_Consulting.pdf': None,
#    '121UCE_Service_Spec_Sheet_UC4_Consulting_v3.2.pdf': None,
#    '1341 Security concerns': None,
#    '135662_Extended _ISP_Audit_DataExchangeViaSFTP_20220831_Report_approval.pdf': None,
#    '135663_Extended _ISP_Audit_AutomaticRequestManagingTool_20220831_Report_approval.pdf': None,
#    '135664_Extended _ISP_Audit_UC4_20220831_Report_approval.pdf': None,
#    '1376 Decide security classes': None,
#    '165': None,
#    '17': None,
#    '19.12.2018_OLA - MS OSA 2 - 2019.pdf': None,
#    '1_1_Managed File Transfer - Requirements': None,
#    '2 - Get Access to Splunk AE via OneIDM': None,
#    '2 - Organizational Topics': None,
#    '2 Service Transition': None,
#    '2 Service Transition AE': None,
#    '2- Common steps for all request types': None,
#    '2- How to get access?': None,
#    '2. ARMT Request Process & SLA': None,
#    '2. Benefits': None,
#    '2. Build Scope': None,
#    '2. Common steps for all request types': None,
#    '2. Configuration Management': None,
#    '2. Overview': None,
#    '2. REST API call': None,
#    '2. RUN Outsystems': None,
#    '2. Test planning Request Management tool': None,
#    '2.1 Application Migration': None,
#    '2.1 Change Management': None,
#    '2.1 Change Management AE': None,
#    '2.1 Run request': None,
#    '2.1- Naming Convention': None,
#    '2.1. Naming Convention': None,
#    '2.1.1 Temporary change in schedule time of Job': None,
#    '2.1.2 Temporary Deactivation of Job': None,
#    '2.1.3 Reactivation of Deactivated Job': None,
#    '2.1.4 Manual execution of Job (One Time)': None,
#    '2.1.4.1 Manual execution of Single object': None,
#    '2.1.5 Breakpoint': None,
#    '2.1.6 Custom Job handling': None,
#    '2.2 Login to development application': None,
#    '2.2 Release and Deployment Management': None,
#    '2.2 Release and Deployment Management AE': None,
#    '2.2 Support request': None,
#    '2.2- List of Template Jobplans and Usages': None,
#    '2.2. BPA Login Creation': None,
#    '2.2.1 Maintenance Support': None,
#    '2.2.2 Year End Support.': None,
#    '2.2.3 Special Calendar Keyword': None,
#    '2.3 IT Service Asset and Configuration Management': None,
#    '2.3 IT Service Asset and Configuration Management AE': None,
#    '2.3 Login to Service Studio': None,
#    '2.3 Recovery Request': None,
#    '2.3- List of Objects that need to be sent for review': None,
#    '2.3. How to skip job running': None,
#    '2.3.4 Query on UC4 Job.': None,
#    '2.4 Knowledge Management': None,
#    '2.4 Knowledge Management AE': None,
#    '2.4- Scheduling - All scenarios (Daily, Weekly, Monthly, Events,…..)': None,
#    '2.4. The Error Notification by Mail': None,
#    '2.5- First run monitoring': None,
#    '2.5. Spool Retention Period': None,
#    '2.6- Steps to Deactivate & activate - Auto SMT creation job': None,
#    '2.8 -> 2.9 Production': None,
#    '2.9 -> 3.0': None,
#    '2010': None,
#    '2013': None,
#    '2015': None,
#    '2015, Dec 04': None,
#    '2015, Jul 02': None,
#    '2015, Nov 17': None,
#    '2015, Nov 30': None,
#    '2015_ExportControlChecklist_CTXC-UC4.xlsx': None,
#    '2016, Apr 06': None,
#    '2016, Apr 29': None,
#    '2016, Aug 18': None,
#    '2016, Dec 04': None,
#    '2016, Dec 09': None,
#    '2016, Dec 29': None,
#    '2016, Feb 08': None,
#    '2016, Feb 19': None,
#    '2016, Jan 12': None,
#    '2016, Jul 01': None,
#    '2016, Jul 13': None,
#    '2016, Jul 15': None,
#    '2016, Jul 19': None,
#    '2016, Jun 02': None,
#    '2016, Mar 11': None,
#    '2016, Mar 16': None,
#    '2016, Mar 17': None,
#    '2016, Mar 18': None,
#    '2016, May 04': None,
#    '2016, May 10': None,
#    '2016, May 13': None,
#    '2016, May 17': None,
#    '2016, May 18': None,
#    '2016, May 24': None,
#    '2016, Nov 25': None,
#    '2016, Oct 04': None,
#    '2016, Oct 13': None,
#    '2016, Sep 06': None,
#    '2016, Sep 13': None,
#    '2016, Sep 15': None,
#    '2016, Sep 22': None,
#    '2016-10-07-One-Pager-FileTransfer-Concept.pptx': None,
#    '2017, Apr 04': None,
#    '2017, Apr 10': None,
#    '2017, Apr 11': None,
#    '2017, Apr 13': None,
#    '2017, Apr 18': None,
#    '2017, Apr 21': None,
#    '2017, Apr 26': None,
#    '2017, Aug 07': None,
#    '2017, Aug 08': None,
#    '2017, Aug 14': None,
#    '2017, Aug 21': None,
#    '2017, Aug 24': None,
#    '2017, Dec 05': None,
#    '2017, Dec 08': None,
#    '2017, Dec 13': None,
#    '2017, Dec 19': None,
#    '2017, Dec 21': None,
#    '2017, Dec 22': None,
#    '2017, Feb 02': None,
#    '2017, Feb 03': None,
#    '2017, Feb 15': None,
#    '2017, Feb 21': None,
#    '2017, Feb 22': None,
#    '2017, Jan 10': None,
#    '2017, Jan 12': None,
#    '2017, Jan 20': None,
#    '2017, Jan 24': None,
#    '2017, Jan 30': None,
#    '2017, Jul 03': None,
#    '2017, Jul 04': None,
#    '2017, Jun 05': None,
#    '2017, Jun 09': None,
#    '2017, Jun 23': None,
#    '2017, Jun 27': None,
#    '2017, Mar 06': None,
#    '2017, Mar 20': None,
#    '2017, May 08': None,
#    '2017, May 11': None,
#    '2017, May 16': None,
#    '2017, May 17': None,
#    '2017, May 23': None,
#    '2017, May 29': None,
#    '2017, May 31': None,
#    '2017, Nov 03': None,
#    '2017, Nov 08': None,
#    '2017, Nov 10': None,
#    '2017, Nov 28': None,
#    '2017, Oct 04': None,
#    '2017, Sep 18': None,
#    '2017, Sep 21': None,
#    '2017, Sep 25': None,
#    '2017, Sep 26': None,
#    '2017: Planned dates for XD': None,
#    '2018, Apr 05': None,
#    '2018, Apr 10': None,
#    '2018, Apr 13': None,
#    '2018, Apr 19': None,
#    '2018, Apr 22': None,
#    '2018, Apr 25': None,
#    '2018, Aug 01': None,
#    '2018, Aug 03': None,
#    '2018, Aug 06': None,
#    '2018, Aug 08': None,
#    '2018, Aug 09': None,
#    '2018, Aug 13': None,
#    '2018, Aug 20': None,
#    '2018, Aug 27': None,
#    '2018, Aug 29': None,
#    '2018, Aug 31': None,
#    '2018, Dec 05': None,
#    '2018, Dec 07': None,
#    '2018, Dec 17': None,
#    '2018, Dec 18': None,
#    '2018, Feb 01': None,
#    '2018, Feb 09': None,
#    '2018, Feb 12': None,
#    '2018, Feb 14': None,
#    '2018, Feb 20': None,
#    '2018, Feb 23': None,
#    '2018, Jan 04': None,
#    '2018, Jan 05': None,
#    '2018, Jan 09': None,
#    '2018, Jan 11': None,
#    '2018, Jan 18': None,
#    '2018, Jan 22': None,
#    '2018, Jul 04': None,
#    '2018, Jul 05': None,
#    '2018, Jul 06': None,
#    '2018, Jul 16': None,
#    '2018, Jul 19': None,
#    '2018, Jul 24': None,
#    '2018, Jul 31': None,
#    '2018, Mar 07': None,
#    '2018, Mar 08': None,
#    '2018, Mar 13': None,
#    '2018, Mar 20': None,
#    '2018, Mar 21': None,
#    '2018, Mar 26': None,
#    '2018, Mar 29': None,
#    '2018, May 07': None,
#    '2018, Nov 19': 'https://inside-docupedia.bosch.com/confluence/pages/diffpagesbyversion.action?pageId=462389207&selectedPageVersions=37&selectedPageVersions=38 "Show changes"',
#    '2018, Nov 21': None,
#    '2018, Nov 29': None,
#    '2018, Nov 30': None,
#    '2018, Oct 02': None,
#    '2018, Oct 23': None,
#    '2018, Oct 30': None,
#    '2018, Sep 04': None,
#    '2018, Sep 07': None,
#    '2018, Sep 10': None,
#    '2018, Sep 18': None,
#    '2018, Sep 19': None,
#    '2018, Sep 20': None,
#    '2018, Sep 21': None,
#    '2018, Sep 25': None,
#    '20181001_Risk-Assessment_CI-on-behalf-GmbH_all.xlsx': None,
#    '2019, Apr 05': None,
#    '2019, Apr 08': None,
#    '2019, Apr 10': None,
#    '2019, Apr 12': None,
#    '2019, Apr 15': None,
#    '2019, Apr 16': None,
#    '2019, Apr 18': None,
#    '2019, Apr 23': None,
#    '2019, Apr 24': None,
#    '2019, Apr 26': None,
#    '2019, Aug 01': None,
#    '2019, Aug 02': None,
#    '2019, Aug 13': None,
#    '2019, Aug 14': None,
#    '2019, Aug 15': None,
#    '2019, Aug 20': None,
#    '2019, Dec 06': None,
#    '2019, Dec 09': None,
#    '2019, Dec 11': None,
#    '2019, Dec 16': None,
#    '2019, Feb 18': None,
#    '2019, Jan 07': None,
#    '2019, Jan 08': None,
#    '2019, Jan 10': None,
#    '2019, Jan 11': None,
#    '2019, Jan 24': None,
#    '2019, Jan 25': None,
#    '2019, Jan 28': None,
#    '2019, Jan 29': None,
#    '2019, Jul 02': None,
#    '2019, Jul 09': None,
#    '2019, Jul 11': None,
#    '2019, Jul 15': None,
#    '2019, Jul 17': None,
#    '2019, Jul 25': None,
#    '2019, Jun 07': None,
#    '2019, Jun 11': None,
#    '2019, Jun 19': None,
#    '2019, Mar 12': None,
#    '2019, Mar 18': None,
#    '2019, Mar 25': None,
#    '2019, Mar 26': None,
#    '2019, Mar 27': None,
#    '2019, Mar 28': None,
#    '2019, May 13': None,
#    '2019, May 14': None,
#    '2019, May 23': None,
#    '2019, Nov 06': None,
#    '2019, Nov 08': None,
#    '2019, Nov 11': None,
#    '2019, Nov 12': None,
#    '2019, Nov 20': None,
#    '2019, Nov 27': None,
#    '2019, Nov 28': None,
#    '2019, Nov 29': None,
#    '2019, Oct 08': None,
#    '2019, Oct 09': None,
#    '2019, Oct 11': None,
#    '2019, Oct 15': None,
#    '2019, Oct 21': None,
#    '2019, Oct 24': None,
#    '2019, Oct 29': None,
#    '2019, Sep 04': None,
#    '2019, Sep 10': None,
#    '2019, Sep 16': None,
#    '2019, Sep 18': None,
#    '2019, Sep 23': None,
#    '2019, Sep 25': None,
#    '2019, Sep 27': None,
#    '2019, Sep 30': None,
#    '2019-04-11Einordnung ARA Fragen.xlsx': None,
#    '2019-12': None,
#    '2020, Apr 03': None,
#    '2020, Apr 06': None,
#    '2020, Apr 07': None,
#    '2020, Apr 09': None,
#    '2020, Apr 15': None,
#    '2020, Apr 22': None,
#    '2020, Apr 27': None,
#    '2020, Apr 30': None,
#    '2020, Aug 13': None,
#    '2020, Aug 14': None,
#    '2020, Aug 20': None,
#    '2020, Aug 23': None,
#    '2020, Aug 24': None,
#    '2020, Aug 28': None,
#    '2020, Dec 02': None,
#    '2020, Dec 03': None,
#    '2020, Dec 04': None,
#    '2020, Dec 09': None,
#    '2020, Dec 10': None,
#    '2020, Dec 30': None,
#    '2020, Feb 03': None,
#    '2020, Feb 04': None,
#    '2020, Feb 05': None,
#    '2020, Feb 11': None,
#    '2020, Feb 13': None,
#    '2020, Feb 18': None,
#    '2020, Feb 21': None,
#    '2020, Feb 24': None,
#    '2020, Feb 25': None,
#    '2020, Jan 08': None,
#    '2020, Jan 09': None,
#    '2020, Jan 15': None,
#    '2020, Jan 17': None,
#    '2020, Jan 23': None,
#    '2020, Jan 28': None,
#    '2020, Jul 01': None,
#    '2020, Jul 06': None,
#    '2020, Jul 16': None,
#    '2020, Jul 23': None,
#    '2020, Jun 02': None,
#    '2020, Jun 03': None,
#    '2020, Jun 19': None,
#    '2020, Jun 24': None,
#    '2020, Jun 30': None,
#    '2020, Mar 03': None,
#    '2020, Mar 05': None,
#    '2020, Mar 06': None,
#    '2020, Mar 09': None,
#    '2020, Mar 10': None,
#    '2020, Mar 12': None,
#    '2020, Mar 17': None,
#    '2020, Mar 23': None,
#    '2020, Mar 24': None,
#    '2020, Mar 25': None,
#    '2020, Mar 30': None,
#    '2020, Mar 31': None,
#    '2020, May 08': None,
#    '2020, May 13': None,
#    '2020, Nov 03': None,
#    '2020, Nov 12': None,
#    '2020, Nov 19': None,
#    '2020, Nov 21': None,
#    '2020, Nov 24': None,
#    '2020, Nov 25': None,
#    '2020, Nov 26': None,
#    '2020, Oct 08': None,
#    '2020, Oct 12': None,
#    '2020, Oct 22': None,
#    '2020, Oct 26': None,
#    '2020, Oct 27': None,
#    '2020, Oct 28': None,
#    '2020, Sep 01': None,
#    '2020, Sep 03': None,
#    '2020, Sep 04': None,
#    '2020, Sep 07': None,
#    '2020, Sep 08': None,
#    '2020, Sep 25': None,
#    '2020, Sep 28': None,
#    '2020, Sep 29': None,
#    '2020, Sep 30': None,
#    '2020-10-21-Securing the SAP Fileshare_v5.pptx': None,
#    '2020_10_Automic_AUT_Roadmap_bosch.pdf': None,
#    '2020_Auswertung_Lasttests_V5.xlsx': None,
#    '2021 O7Risk_Analysis.pdf': None,
#    '2021 Operation Manual.pdf': None,
#    '2021, Apr 01': None,
#    '2021, Apr 07': None,
#    '2021, Apr 13': None,
#    '2021, Apr 19': None,
#    '2021, Apr 21': None,
#    '2021, Apr 27': None,
#    '2021, Apr 30': None,
#    '2021, Aug 04': None,
#    '2021, Aug 13': None,
#    '2021, Aug 23': None,
#    '2021, Aug 24': None,
#    '2021, Aug 27': None,
#    '2021, Aug 31': None,
#    '2021, Dec 01': None,
#    '2021, Dec 09': None,
#    '2021, Dec 17': None,
#    '2021, Feb 01': None,
#    '2021, Feb 02': None,
#    '2021, Feb 03': None,
#    '2021, Feb 05': None,
#    '2021, Feb 08': None,
#    '2021, Feb 09': None,
#    '2021, Feb 10': None,
#    '2021, Feb 11': None,
#    '2021, Feb 12': None,
#    '2021, Feb 16': None,
#    '2021, Feb 17': None,
#    '2021, Feb 22': None,
#    '2021, Feb 23': None,
#    '2021, Feb 24': None,
#    '2021, Feb 25': None,
#    '2021, Feb 26': None,
#    '2021, Jan 07': None,
#    '2021, Jan 13': None,
#    '2021, Jan 21': None,
#    '2021, Jan 25': None,
#    '2021, Jan 26': None,
#    '2021, Jul 01': None,
#    '2021, Jul 14': None,
#    '2021, Jul 16': None,
#    '2021, Jul 19': None,
#    '2021, Jul 20': None,
#    '2021, Jul 27': None,
#    '2021, Jun 01': None,
#    '2021, Jun 07': None,
#    '2021, Jun 08': None,
#    '2021, Jun 10': None,
#    '2021, Jun 11': None,
#    '2021, Jun 15': None,
#    '2021, Jun 18': None,
#    '2021, Jun 21': None,
#    '2021, Jun 28': None,
#    '2021, Jun 30': None,
#    '2021, Mar 01': None,
#    '2021, Mar 02': None,
#    '2021, Mar 03': None,
#    '2021, Mar 04': None,
#    '2021, Mar 05': None,
#    '2021, Mar 12': None,
#    '2021, Mar 15': None,
#    '2021, Mar 19': None,
#    '2021, Mar 22': None,
#    '2021, Mar 23': None,
#    '2021, Mar 26': None,
#    '2021, Mar 29': None,
#    '2021, Mar 30': None,
#    '2021, May 05': None,
#    '2021, May 10': None,
#    '2021, May 25': None,
#    '2021, May 26': None,
#    '2021, May 27': None,
#    '2021, Nov 03': None,
#    '2021, Nov 23': None,
#    '2021, Nov 29': None,
#    '2021, Oct 01': None,
#    '2021, Oct 11': None,
#    '2021, Oct 25': None,
#    '2021, Sep 01': None,
#    '2021, Sep 17': None,
#    '2021, Sep 21': None,
#    '2021, Sep 29': None,
#    '2021-08-13-FT-Vulnerability.pptx': None,
#    '20210928_Selbstcheck_POD³ 1.1.xlsm': None,
#    '20210928_Selbstcheck_TCT - Nexeed Insertion.xlsm': None,
#    '20210928_Selbstcheck_TCT Adapter.xlsm': None,
#    '2021_ARA_Approval_Control.pdf': None,
#    '2022, Apr 01': None,
#    '2022, Apr 11': None,
#    '2022, Apr 13': None,
#    '2022, Apr 14': None,
#    '2022, Apr 19': None,
#    '2022, Apr 25': None,
#    '2022, Apr 28': None,
#    '2022, Apr 29': None,
#    '2022, Aug 01': None,
#    '2022, Aug 11': None,
#    '2022, Aug 16': None,
#    '2022, Aug 17': None,
#    '2022, Aug 19': None,
#    '2022, Aug 22': None,
#    '2022, Aug 23': None,
#    '2022, Aug 24': None,
#    '2022, Aug 26': None,
#    '2022, Aug 29': None,
#    '2022, Aug 30': None,
#    '2022, Dec 01': None,
#    '2022, Dec 05': None,
#    '2022, Dec 06': None,
#    '2022, Dec 07': None,
#    '2022, Dec 13': None,
#    '2022, Dec 20': None,
#    '2022, Dec 22': None,
#    '2022, Dec 29': None,
#    '2022, Feb 03': None,
#    '2022, Feb 04': None,
#    '2022, Feb 08': None,
#    '2022, Feb 09': None,
#    '2022, Feb 11': None,
#    '2022, Feb 16': None,
#    '2022, Feb 18': None,
#    '2022, Feb 28': None,
#    '2022, Jan 04': None,
#    '2022, Jan 05': None,
#    '2022, Jan 07': None,
#    '2022, Jan 17': None,
#    '2022, Jan 18': None,
#    '2022, Jan 19': None,
#    '2022, Jan 25': None,
#    '2022, Jan 27': None,
#    '2022, Jul 06': None,
#    '2022, Jul 12': None,
#    '2022, Jul 13': None,
#    '2022, Jul 14': None,
#    '2022, Jul 15': None,
#    '2022, Jul 19': None,
#    '2022, Jul 21': None,
#    '2022, Jul 26': None,
#    '2022, Jul 28': None,
#    '2022, Jun 01': None,
#    '2022, Jun 02': None,
#    '2022, Jun 03': None,
#    '2022, Jun 08': None,
#    '2022, Jun 09': None,
#    '2022, Jun 10': None,
#    '2022, Jun 15': None,
#    '2022, Jun 17': None,
#    '2022, Jun 21': None,
#    '2022, Jun 23': None,
#    '2022, Jun 24': None,
#    '2022, Jun 27': None,
#    '2022, Jun 28': None,
#    '2022, Jun 29': None,
#    '2022, Mar 02': None,
#    '2022, Mar 03': None,
#    '2022, Mar 04': None,
#    '2022, Mar 07': None,
#    '2022, Mar 09': None,
#    '2022, Mar 10': None,
#    '2022, Mar 17': None,
#    '2022, Mar 21': None,
#    '2022, Mar 22': None,
#    '2022, Mar 23': None,
#    '2022, Mar 24': None,
#    '2022, Mar 25': None,
#    '2022, Mar 28': None,
#    '2022, Mar 30': None,
#    '2022, Mar 31': None,
#    '2022, May 06': None,
#    '2022, May 09': None,
#    '2022, May 11': None,
#    '2022, May 18': None,
#    '2022, May 20': None,
#    '2022, May 24': None,
#    '2022, May 26': None,
#    '2022, May 29': None,
#    '2022, May 30': None,
#    '2022, Nov 03': None,
#    '2022, Nov 04': None,
#    '2022, Nov 11': None,
#    '2022, Nov 17': None,
#    '2022, Nov 22': None,
#    '2022, Nov 29': None,
#    '2022, Oct 04': None,
#    '2022, Oct 05': None,
#    '2022, Oct 12': None,
#    '2022, Oct 13': None,
#    '2022, Oct 14': None,
#    '2022, Oct 17': None,
#    '2022, Oct 19': None,
#    '2022, Oct 20': None,
#    '2022, Oct 24': None,
#    '2022, Oct 25': None,
#    '2022, Oct 31': None,
#    '2022, Sep 01': None,
#    '2022, Sep 02': None,
#    '2022, Sep 06': None,
#    '2022, Sep 09': None,
#    '2022, Sep 15': None,
#    '2022, Sep 19': None,
#    '2022, Sep 20': None,
#    '2022, Sep 22': None,
#    '2022, Sep 26': None,
#    '2022, Sep 28': None,
#    '2022, Sep 29': None,
#    '2022, Sep 30': None,
#    '2023, Apr 03': None,
#    '2023, Apr 05': None,
#    '2023, Apr 10': None,
#    '2023, Apr 11': None,
#    '2023, Apr 13': None,
#    '2023, Apr 14': None,
#    '2023, Apr 15': None,
#    '2023, Apr 18': None,
#    '2023, Apr 20': None,
#    '2023, Apr 24': None,
#    '2023, Apr 26': None,
#    '2023, Apr 27': None,
#    '2023, Apr 28': None,
#    '2023, Aug 02': None,
#    '2023, Aug 03': None,
#    '2023, Aug 08': None,
#    '2023, Aug 09': None,
#    '2023, Aug 11': None,
#    '2023, Aug 15': None,
#    '2023, Aug 16': None,
#    '2023, Aug 17': None,
#    '2023, Aug 24': None,
#    '2023, Aug 25': None,
#    '2023, Aug 28': None,
#    '2023, Aug 30': None,
#    '2023, Aug 31': None,
#    '2023, Dec 01': None,
#    '2023, Dec 04': None,
#    '2023, Dec 05': None,
#    '2023, Dec 06': None,
#    '2023, Dec 11': None,
#    '2023, Dec 13': None,
#    '2023, Dec 14': None,
#    '2023, Dec 15': None,
#    '2023, Dec 19': None,
#    '2023, Dec 20': None,
#    '2023, Dec 21': None,
#    '2023, Feb 01': None,
#    '2023, Feb 02': None,
#    '2023, Feb 06': None,
#    '2023, Feb 07': None,
#    '2023, Feb 08': None,
#    '2023, Feb 09': None,
#    '2023, Feb 10': None,
#    '2023, Feb 15': None,
#    '2023, Feb 21': None,
#    '2023, Feb 22': None,
#    '2023, Feb 24': None,
#    '2023, Feb 27': None,
#    '2023, Feb 28': None,
#    '2023, Jan 02': None,
#    '2023, Jan 03': None,
#    '2023, Jan 04': None,
#    '2023, Jan 05': None,
#    '2023, Jan 06': None,
#    '2023, Jan 09': None,
#    '2023, Jan 10': None,
#    '2023, Jan 11': None,
#    '2023, Jan 12': None,
#    '2023, Jan 13': None,
#    '2023, Jan 16': None,
#    '2023, Jan 17': None,
#    '2023, Jan 18': None,
#    '2023, Jan 20': None,
#    '2023, Jan 23': None,
#    '2023, Jan 26': None,
#    '2023, Jan 27': None,
#    '2023, Jan 30': None,
#    '2023, Jul 03': None,
#    '2023, Jul 04': None,
#    '2023, Jul 05': None,
#    '2023, Jul 06': None,
#    '2023, Jul 10': None,
#    '2023, Jul 13': None,
#    '2023, Jul 19': None,
#    '2023, Jul 25': None,
#    '2023, Jul 26': None,
#    '2023, Jul 27': None,
#    '2023, Jul 28': None,
#    '2023, Jun 02': None,
#    '2023, Jun 05': None,
#    '2023, Jun 06': None,
#    '2023, Jun 08': None,
#    '2023, Jun 09': None,
#    '2023, Jun 12': None,
#    '2023, Jun 13': None,
#    '2023, Jun 14': None,
#    '2023, Jun 15': None,
#    '2023, Jun 20': None,
#    '2023, Jun 22': None,
#    '2023, Jun 23': None,
#    '2023, Jun 26': None,
#    '2023, Jun 27': None,
#    '2023, Jun 28': None,
#    '2023, Jun 29': None,
#    '2023, Jun 30': None,
#    '2023, Mar 01': None,
#    '2023, Mar 02': None,
#    '2023, Mar 03': None,
#    '2023, Mar 10': None,
#    '2023, Mar 13': None,
#    '2023, Mar 14': None,
#    '2023, Mar 15': None,
#    '2023, Mar 17': None,
#    '2023, Mar 21': None,
#    '2023, Mar 23': None,
#    '2023, Mar 27': None,
#    '2023, Mar 28': None,
#    '2023, Mar 30': None,
#    '2023, Mar 31': None,
#    '2023, May 03': None,
#    '2023, May 05': None,
#    '2023, May 09': None,
#    '2023, May 10': None,
#    '2023, May 11': None,
#    '2023, May 12': None,
#    '2023, May 15': None,
#    '2023, May 16': None,
#    '2023, May 17': None,
#    '2023, May 24': None,
#    '2023, May 25': None,
#    '2023, May 30': None,
#    '2023, May 31': None,
#    '2023, Nov 01': None,
#    '2023, Nov 02': None,
#    '2023, Nov 03': None,
#    '2023, Nov 04': None,
#    '2023, Nov 06': None,
#    '2023, Nov 07': None,
#    '2023, Nov 08': None,
#    '2023, Nov 09': None,
#    '2023, Nov 10': None,
#    '2023, Nov 13': None,
#    '2023, Nov 15': None,
#    '2023, Nov 16': None,
#    '2023, Nov 17': None,
#    '2023, Nov 20': None,
#    '2023, Nov 22': None,
#    '2023, Nov 23': None,
#    '2023, Nov 27': None,
#    '2023, Nov 28': None,
#    '2023, Nov 30': None,
#    '2023, Oct 05': None,
#    '2023, Oct 06': None,
#    '2023, Oct 09': None,
#    '2023, Oct 10': None,
#    '2023, Oct 17': None,
#    '2023, Oct 18': None,
#    '2023, Oct 19': None,
#    '2023, Oct 24': None,
#    '2023, Oct 25': None,
#    '2023, Oct 31': None,
#    '2023, Sep 01': None,
#    '2023, Sep 03': None,
#    '2023, Sep 06': None,
#    '2023, Sep 08': None,
#    '2023, Sep 12': None,
#    '2023, Sep 14': None,
#    '2023, Sep 15': None,
#    '2023, Sep 18': None,
#    '2023, Sep 20': None,
#    '2023, Sep 21': None,
#    '2023, Sep 22': None,
#    '2023, Sep 26': None,
#    '2023, Sep 27': None,
#    '2023, Sep 28': None,
#    '2023-09-21 Flowable Sprint 1 (Review)': None,
#    '2023-10-05 Flowable Sprint 2': None,
#    '2023-10-19 Flowable Sprint 3': None,
#    '2023-11-02 Flowable Sprint 4': None,
#    '2023-11-16 Flowable Sprint 5': None,
#    '2023-11-30 Flowable Sprint 6': None,
#    '2023-12-14 Flowable Sprint 7 🎄': None,
#    '20231019_OperatorSelfChec_ASP.pdf': None,
#    '20231019_OperatorsSelfCheck_AE_INFO_APP (1).pdf': None,
#    '20231214 - Flowable ISDS Checklist CD-02900-007_ANH_Z_EN_2022-04-27.xlsm': None,
#    '20232012_Flowable_AG_Pentest_Report.zip': None,
#    '2023_11_C-AU-Audit_BD-PO-Overview.pptx': None,
#    '2023_UC4_ARA_OperatorSelfCheck.pdf': None,
#    '2024, Apr 02': None,
#    '2024, Apr 03': None,
#    '2024, Apr 04': None,
#    '2024, Apr 05': None,
#    '2024, Apr 07': None,
#    '2024, Apr 08': None,
#    '2024, Apr 10': None,
#    '2024, Apr 11': None,
#    '2024, Apr 12': None,
#    '2024, Apr 15': None,
#    '2024, Apr 16': None,
#    '2024, Apr 17': None,
#    ...},
#   'title': '[Customers and Users Area](https://inside-docupedia.bosch.com/confluence/display/GWA/Customers+and+Users+Area)'},
#  {'author': 'Reitz Martin (BD/DPA-GTC3 BD/DPA-CAL-Sq1)',
#   'content': '1. [Pages](https://inside-docupedia.bosch.com/confluence/collector/pages.action?key=GWA&src=breadcrumbs-collector)\n2. [Home](https://inside-docupedia.bosch.com/confluence/display/GWA/Home?src=breadcrumbs-parent)\n\n# [ALPS Team Area](https://inside-docupedia.bosch.com/confluence/display/GWA/ALPS+Team+Area)\n\n* Created by  [Reitz Martin (BD/DPA-GTC3 BD/DPA-CAL-Sq1)](https://inside-docupedia.bosch.com/confluence/display/~REM1IMB), last modified on [2025, Jan 10](https://inside-docupedia.bosch.com/confluence/pages/diffpagesbyversion.action?pageId=5114305552&selectedPageVersions=3&selectedPageVersions=4 "Show changes")\n  \n  Current Version V 4\n[Page Info](# "Space Info")\n\n\n\n## Team\n\n![](https://inside-docupedia.bosch.com/confluence/download/attachments/5114305552/ALPS_Team.png?version=1&modificationDate=1736521294000&api=v2)\n\n### BV+3 level description of the Agile Delivery Unit / Squad\n\n* Name:\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Automation & LC P/S Development\n* Nickname:\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ALPS\n* Department:\xa0\xa0\xa0\xa0 BD/DPA-CAL-Sq1\n* Primary KPI:\xa0\xa0\xa0\xa0\xa0 PCR - Competitiveness\n* Secondary KPI:\xa0 NPV - Value for customer\n* Mission:\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 We build up new automation- and low-code P/S to support the Bosch digitalization.\n* Activities:\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Develop automation- and low code products and services in an agile way.',
#   'created_date': '2025, Jan 10',
#   'features': ['Created by  [Reitz Martin (BD/DPA-GTC3 BD/DPA-CAL-Sq1)](https://inside-docupedia.bosch.com/confluence/display/~REM1IMB), last modified on [2025, Jan 10](https://inside-docupedia.bosch.com/confluence/pages/diffpagesbyversion.action?pageId=5114305552&selectedPageVersions=3&selectedPageVersions=4 "Show changes")',
#    'Name:\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Automation & LC P/S Development',
#    'Nickname:\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ALPS',
#    'Department:\xa0\xa0\xa0\xa0 BD/DPA-CAL-Sq1',
#    'Primary KPI:\xa0\xa0\xa0\xa0\xa0 PCR - Competitiveness',
#    'Secondary KPI:\xa0 NPV - Value for customer',
#    'Mission:\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 We build up new automation- and low-code P/S to support the Bosch digitalization.',
#    'Activities:\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Develop automation- and low code products and services in an agile way.'],
#   'links': {'![': None,
#    '![Home': None,
#    '![Users profile picture': None,
#    '"BAT"': None,
#    '"Declaration of Obligation for Administrators"': None,
#    '"EISA"': None,
#    '"Hierarchy View"': None,
#    '"Provision a new S3 bucket"': None,
#    '"Sending mails using the E-Mail task"': None,
#    '#1636': None,
#    '#1992': None,
#    '#1996': None,
#    '#2.2 SAML / OpenID Connect (OIDC)\xa0Authentication': None,
#    '#2080': None,
#    '#2336': None,
#    '#2374': None,
#    '#2412': None,
#    '#2432': None,
#    '#2505': None,
#    '#Request Status': None,
#    "'0' byte files": None,
#    '(Backup link)': None,
#    '(Haken)': None,
#    '(L2)': None,
#    '(Logon like on EUP4).': None,
#    '(NEU) Statistics of jobs': None,
#    '(O1)': None,
#    '(O3)': None,
#    '(O5)': None,
#    '(Recommended Learning Videos in CI Steering Enabling & Knowledge Hub': None,
#    '(S) How to get access to Splunk Data (via oneIDM)': None,
#    '(Verpflichtungserklärung)': None,
#    '(blue star)': None,
#    '(error)': None,
#    '(grey lightbulb)': None,
#    '(info)': None,
#    '(lightbulb)': None,
#    '(minus)': None,
#    '(plus)': None,
#    '(rbsg) File Share Migration': None,
#    '(red star)': None,
#    '(see separate description': None,
#    '(smile)': None,
#    '(spl02) Application Logging - splunk (ACTIVE)': None,
#    '(star)': None,
#    '(tick)': None,
#    '(warning)': None,
#    '(wink)': None,
#    ')': None,
#    '**ARMT**': None,
#    '**BD Interface Life Cycle Management**': None,
#    '**BD Quality Strategy** (2022)': None,
#    '**BD(CI) Quality Strategy**\xa0(2022)': None,
#    '**BoM+1 area:**': None,
#    '**Bosch Acronym Index**': None,
#    '**Bosch CERT - Dashboard**': None,
#    '**Bosch IDM**': None,
#    '**CD 02900 - ISP-CD Information Security and Data Protection**': None,
#    '**CD 07000 - Cyber Security Management System**': None,
#    '**CD 07900 - IT Security**': None,
#    '**CDQ 00907 - Complain Process**': None,
#    '**CI Steering**': None,
#    '**CI/PI - Risk Management**': None,
#    '**CI_ISA3 New global System Owner Concept 2018-04.pptx**': None,
#    '**Common Documents - IT Service Continuity Management O7**': None,
#    '**Docupedia**': None,
#    '**Draft: L4 - Deployment Management**': None,
#    '**Draft: O5 - Event Management**': None,
#    '**Draft: O9 - Availability Management**': None,
#    '**Draft: U3 - Continual Improvement**': None,
#    '**Eisenhut Helmut (CI/DAP51.3)**': None,
#    '**Enterprise Alert**': None,
#    '**Get Access**': None,
#    '**IDM LINK**': None,
#    '**IT P/S/S Excellence Process (IT PEP)**': None,
#    '**IT Service Portal (ITSP)**': None,
#    '**ITOM - Template Usage Guide**': None,
#    '**International**': None,
#    '**K3 - Charging**': None,
#    '**KMS Home**': None,
#    '**L2**': None,
#    '**L3 - Request Fulfillment**': None,
#    '**L3 -** **Standard Service Request criteria**': None,
#    '**L4**': None,
#    '**LeanIX definition**': None,
#    '**M3**': None,
#    '**M5 - Information Security Management**': None,
#    '**Necessary Tools**': None,
#    '**O1 - Incident Management**': None,
#    '**O2 - Problem Management**': None,
#    '**O3 - Change Management**': None,
#    '**O5**': None,
#    '**O6 - Configuration Manager**': None,
#    '**O7 - IT Service Continuity Management**': None,
#    '**O9**': None,
#    '**OneNote**': None,
#    '**Organization of Bosch Group**': None,
#    '**POA BGN Page**': None,
#    '**Planisware**': None,
#    '**RBGF 00104 - Risk Management System**': None,
#    '**RBGF 00105 - Information Security and Data Protection (ISP)**': None,
#    '**RBGF 00182 - Product Development Code**': None,
#    '**RUN**': None,
#    '**SMT - Service Management Toolsuite**': None,
#    '**SPoI - Single Point of Information**': None,
#    '**SUPPORT**': None,
#    '**SharePoint**': None,
#    '**Splunk**': None,
#    '**Start SMT-CMDB**': None,
#    '**T&R**:\xa0 OSATWO-1765': None,
#    '**U2 - Knowledge Management**': None,
#    '**U3 - Continual Improvement**': None,
#    '**U3**': None,
#    '**here**': None,
#    '**https://inside-docupedia.bosch.com/confluence/pages/viewpage.action?pageId=429723274**': None,
#    '**https://inside-docupedia.bosch.com/confluence/x/i1RZ1Q**': None,
#    '**https://rb-armt.bosch.com/jrm/**': None,
#    '**https://rb-smt.de.bosch.com**': None,
#    '**link**': None,
#    '**rb-eut1app1.server.bosch.com**': None,
#    '**this Link**': None,
#    '*BD/OS Process description*': None,
#    '*Continuity Management*': None,
#    '*fe0vmc2629.de.bosch.com*.': None,
#    '*oneIDM (bosch.com)*': None,
#    '.': None,
#    '/': None,
#    '/AEFRAMEWORK/': None,
#    '/Compas/': None,
#    '/EXTENSIONS/': None,
#    '/IDM/': None,
#    '/Supportutils/': None,
#    '/extensions/ae/<system>/healthStatus': None,
#    '/local/home/x0padm/.ssh/known_hosts': None,
#    '/objectExist?objectName=': None,
#    '0 Preamble': None,
#    '0 Preamble TODO': None,
#    '01 Introduction and Goals': None,
#    '01 Introduction and Goals#01IntroductionandGoals-1.1.4FunctionalRequirementsflw_high_lvl_req': None,
#    '01 Introduction and Goals#01IntroductionandGoals-1.2Stakeholders': None,
#    '01 Introduction and Goals#01IntroductionandGoals-1.3.1QualitycharacteristicsandNon-functionalRequirementsflw_non_func_req': None,
#    '01. Contacts': None,
#    '01016417': None,
#    '01159287': None,
#    '02 Constraints': None,
#    '02. Session Schedule': None,
#    '02. Sessions': None,
#    '03 System Scope and Context': None,
#    '04 Solution Strategy': None,
#    '05 Building Blocks': None,
#    '06 Runtime View': None,
#    '07 Deployment View': None,
#    '08 Crosscutting Concepts': None,
#    '09 Design Decisions': None,
#    '1': None,
#    '1 - Concept Zone': None,
#    '1 - Purpose': None,
#    '1 Service Design': None,
#    '1 Service Design AE': None,
#    '1- ARMT Request Process Description': None,
#    '1- Purpose': None,
#    '1. ARMT Request Process Description': None,
#    '1. Application Parameters': None,
#    '1. General Information_RUN Topic': None,
#    '1. Introduction Request Management tool': None,
#    '1. Members': None,
#    '1. Onboarding RUN Outsystems': None,
#    '1. Purpose': None,
#    '1. RASIC': None,
#    '1. Responsibility & Approval': None,
#    '1.1 How to request OutSystems role on oneIDM': None,
#    '1.1 Service Description': None,
#    '1.1 Service Description AE': None,
#    '1.1- Create Requests': None,
#    '1.1. Create Requests': None,
#    '1.2 Access to your OutSystems Application': None,
#    '1.2 General Overview About AWI': None,
#    '1.2 Service Level Management': None,
#    '1.2 Service Level Management AE': None,
#    '1.2- Update and Delete Requests': None,
#    '1.2. Update and Delete Requests': None,
#    '1.3 Risk Management': None,
#    '1.3 Risk Management TODO': None,
#    '1.3 Run Scope': None,
#    '1.3- Special and Complex Requests': None,
#    '1.3. Special and Complex Requests': None,
#    '1.4 Capacity Management': None,
#    '1.4 Capacity Management AE': None,
#    '1.4 Run Out Of Scope': None,
#    '1.5 Availability Management': None,
#    '1.5 Availability Management AE': None,
#    '1.5 Run Daily Activities': None,
#    '1.6 IT Service Continuity Management': None,
#    '1.6 IT Service Continuity Management AE': None,
#    '1.6 Tool Access list - Onboarding': None,
#    '1.6.1 Access to AEINFO APP': None,
#    '1.6.2 Access to Request Management(ARMT)': None,
#    '1.6.3 Access to ITOE Enterprise Alerting': None,
#    '1.6.4 Access to SPLUNK via OneIdm': None,
#    '1.7 Data Protection and Privacy': None,
#    '1.7 Data Protection and Privacy AE': None,
#    '1.8 Compliance Management': None,
#    '1.8 Compliance Management TODO': None,
#    '1.9 Cyber Security TODO': None,
#    '1.9 IT Security': None,
#    '1.Members_RUN': None,
#    '10 Quality': None,
#    '10-2019.pdf': None,
#    '10. Change History': None,
#    '10. Header Info': None,
#    '1055_Email Template.xlsx': None,
#    '11 Risks': None,
#    '11. Scheduled jobs in UC4': None,
#    '1113_Feedback.pptx': None,
#    '116': None,
#    '12 Glossary': None,
#    '12. Expiration Alerts': None,
#    '12.2': None,
#    '12.2.2_lizenzen.zip': None,
#    '12.3': None,
#    '121ARA_Service_Spec_Sheet_ARA_Service.pdf': None,
#    '121ARA_Service_Spec_Sheet_ARA_Service_V1.2.pdf': None,
#    '121FTP_Service_Spec_Sheet_SFTP_Data_Exchange.pdf': None,
#    '121FTP_Service_Spec_Sheet_SFTP_Data_Exchange_V1.7.pdf': None,
#    '121FTS_Service_Spec_Sheet_UC4_FileTransfer_V1.0.pdf': None,
#    '121UC4_Service_Spec_Sheet_UC4_Administration.pdf': None,
#    '121UC4_Service_Spec_Sheet_UC4_Administration_v3.2.pdf': None,
#    '121UCE_Service_Spec_Sheet_UC4_Consulting.pdf': None,
#    '121UCE_Service_Spec_Sheet_UC4_Consulting_v3.2.pdf': None,
#    '1341 Security concerns': None,
#    '135662_Extended _ISP_Audit_DataExchangeViaSFTP_20220831_Report_approval.pdf': None,
#    '135663_Extended _ISP_Audit_AutomaticRequestManagingTool_20220831_Report_approval.pdf': None,
#    '135664_Extended _ISP_Audit_UC4_20220831_Report_approval.pdf': None,
#    '1376 Decide security classes': None,
#    '165': None,
#    '17': None,
#    '19.12.2018_OLA - MS OSA 2 - 2019.pdf': None,
#    '1_1_Managed File Transfer - Requirements': None,
#    '2 - Get Access to Splunk AE via OneIDM': None,
#    '2 - Organizational Topics': None,
#    '2 Service Transition': None,
#    '2 Service Transition AE': None,
#    '2- Common steps for all request types': None,
#    '2- How to get access?': None,
#    '2. ARMT Request Process & SLA': None,
#    '2. Benefits': None,
#    '2. Build Scope': None,
#    '2. Common steps for all request types': None,
#    '2. Configuration Management': None,
#    '2. Overview': None,
#    '2. REST API call': None,
#    '2. RUN Outsystems': None,
#    '2. Test planning Request Management tool': None,
#    '2.1 Application Migration': None,
#    '2.1 Change Management': None,
#    '2.1 Change Management AE': None,
#    '2.1 Run request': None,
#    '2.1- Naming Convention': None,
#    '2.1. Naming Convention': None,
#    '2.1.1 Temporary change in schedule time of Job': None,
#    '2.1.2 Temporary Deactivation of Job': None,
#    '2.1.3 Reactivation of Deactivated Job': None,
#    '2.1.4 Manual execution of Job (One Time)': None,
#    '2.1.4.1 Manual execution of Single object': None,
#    '2.1.5 Breakpoint': None,
#    '2.1.6 Custom Job handling': None,
#    '2.2 Login to development application': None,
#    '2.2 Release and Deployment Management': None,
#    '2.2 Release and Deployment Management AE': None,
#    '2.2 Support request': None,
#    '2.2- List of Template Jobplans and Usages': None,
#    '2.2. BPA Login Creation': None,
#    '2.2.1 Maintenance Support': None,
#    '2.2.2 Year End Support.': None,
#    '2.2.3 Special Calendar Keyword': None,
#    '2.3 IT Service Asset and Configuration Management': None,
#    '2.3 IT Service Asset and Configuration Management AE': None,
#    '2.3 Login to Service Studio': None,
#    '2.3 Recovery Request': None,
#    '2.3- List of Objects that need to be sent for review': None,
#    '2.3. How to skip job running': None,
#    '2.3.4 Query on UC4 Job.': None,
#    '2.4 Knowledge Management': None,
#    '2.4 Knowledge Management AE': None,
#    '2.4- Scheduling - All scenarios (Daily, Weekly, Monthly, Events,…..)': None,
#    '2.4. The Error Notification by Mail': None,
#    '2.5- First run monitoring': None,
#    '2.5. Spool Retention Period': None,
#    '2.6- Steps to Deactivate & activate - Auto SMT creation job': None,
#    '2.8 -> 2.9 Production': None,
#    '2.9 -> 3.0': None,
#    '2010': None,
#    '2013': None,
#    '2015': None,
#    '2015, Dec 04': None,
#    '2015, Jul 02': None,
#    '2015, Nov 17': None,
#    '2015, Nov 30': None,
#    '2015_ExportControlChecklist_CTXC-UC4.xlsx': None,
#    '2016, Apr 06': None,
#    '2016, Apr 29': None,
#    '2016, Aug 18': None,
#    '2016, Dec 04': None,
#    '2016, Dec 09': None,
#    '2016, Dec 29': None,
#    '2016, Feb 08': None,
#    '2016, Feb 19': None,
#    '2016, Jan 12': None,
#    '2016, Jul 01': None,
#    '2016, Jul 13': None,
#    '2016, Jul 15': None,
#    '2016, Jul 19': None,
#    '2016, Jun 02': None,
#    '2016, Mar 11': None,
#    '2016, Mar 16': None,
#    '2016, Mar 17': None,
#    '2016, Mar 18': None,
#    '2016, May 04': None,
#    '2016, May 10': None,
#    '2016, May 13': None,
#    '2016, May 17': None,
#    '2016, May 18': None,
#    '2016, May 24': None,
#    '2016, Nov 25': None,
#    '2016, Oct 04': None,
#    '2016, Oct 13': None,
#    '2016, Sep 06': None,
#    '2016, Sep 13': None,
#    '2016, Sep 15': None,
#    '2016, Sep 22': None,
#    '2016-10-07-One-Pager-FileTransfer-Concept.pptx': None,
#    '2017, Apr 04': None,
#    '2017, Apr 10': None,
#    '2017, Apr 11': None,
#    '2017, Apr 13': None,
#    '2017, Apr 18': None,
#    '2017, Apr 21': None,
#    '2017, Apr 26': None,
#    '2017, Aug 07': None,
#    '2017, Aug 08': None,
#    '2017, Aug 14': None,
#    '2017, Aug 21': None,
#    '2017, Aug 24': None,
#    '2017, Dec 05': None,
#    '2017, Dec 08': None,
#    '2017, Dec 13': None,
#    '2017, Dec 19': None,
#    '2017, Dec 21': None,
#    '2017, Dec 22': None,
#    '2017, Feb 02': None,
#    '2017, Feb 03': None,
#    '2017, Feb 15': None,
#    '2017, Feb 21': None,
#    '2017, Feb 22': None,
#    '2017, Jan 10': None,
#    '2017, Jan 12': None,
#    '2017, Jan 20': None,
#    '2017, Jan 24': None,
#    '2017, Jan 30': None,
#    '2017, Jul 03': None,
#    '2017, Jul 04': None,
#    '2017, Jun 05': None,
#    '2017, Jun 09': None,
#    '2017, Jun 23': None,
#    '2017, Jun 27': None,
#    '2017, Mar 06': None,
#    '2017, Mar 20': None,
#    '2017, May 08': None,
#    '2017, May 11': None,
#    '2017, May 16': None,
#    '2017, May 17': None,
#    '2017, May 23': None,
#    '2017, May 29': None,
#    '2017, May 31': None,
#    '2017, Nov 03': None,
#    '2017, Nov 08': None,
#    '2017, Nov 10': None,
#    '2017, Nov 28': None,
#    '2017, Oct 04': None,
#    '2017, Sep 18': None,
#    '2017, Sep 21': None,
#    '2017, Sep 25': None,
#    '2017, Sep 26': None,
#    '2017: Planned dates for XD': None,
#    '2018, Apr 05': None,
#    '2018, Apr 10': None,
#    '2018, Apr 13': None,
#    '2018, Apr 19': None,
#    '2018, Apr 22': None,
#    '2018, Apr 25': None,
#    '2018, Aug 01': None,
#    '2018, Aug 03': None,
#    '2018, Aug 06': None,
#    '2018, Aug 08': None,
#    '2018, Aug 09': None,
#    '2018, Aug 13': None,
#    '2018, Aug 20': None,
#    '2018, Aug 27': None,
#    '2018, Aug 29': None,
#    '2018, Aug 31': None,
#    '2018, Dec 05': None,
#    '2018, Dec 07': None,
#    '2018, Dec 17': None,
#    '2018, Dec 18': None,
#    '2018, Feb 01': None,
#    '2018, Feb 09': None,
#    '2018, Feb 12': None,
#    '2018, Feb 14': None,
#    '2018, Feb 20': None,
#    '2018, Feb 23': None,
#    '2018, Jan 04': None,
#    '2018, Jan 05': None,
#    '2018, Jan 09': None,
#    '2018, Jan 11': None,
#    '2018, Jan 18': None,
#    '2018, Jan 22': None,
#    '2018, Jul 04': None,
#    '2018, Jul 05': None,
#    '2018, Jul 06': None,
#    '2018, Jul 16': None,
#    '2018, Jul 19': None,
# ...
#    '2018, Aug 01': None,
#    '2018, Aug 03': None,
#    '2018, Aug 06': None,
#    '2018, Aug 08': None,
#    '2018, Aug 09': None,
#    '2018, Aug 13': None,
#    '2018, Aug 20': None,
#    '2018, Aug 27': None,
#    '2018, Aug 29': None,
#    '2018, Aug 31': None,
#    '2018, Dec 05': None,
#    '2018, Dec 07': None,
#    '2018, Dec 17': None,
#    '2018, Dec 18': None,
#    '2018, Feb 01': None,
#    '2018, Feb 09': None,
#    '2018, Feb 12': None,
#    '2018, Feb 14': None,
#    '2018, Feb 20': None,
#    '2018, Feb 23': None,
#    '2018, Jan 04': None,
#    '2018, Jan 05': None,
#    '2018, Jan 09': None,
#    '2018, Jan 11': None,
#    '2018, Jan 18': None,
#    '2018, Jan 22': None,
#    '2018, Jul 04': None,
#    '2018, Jul 05': None,
#    '2018, Jul 06': None,
#    '2018, Jul 16': None,
#    '2018, Jul 19': None,
#    '2018, Jul 24': None,
#    '2018, Jul 31': None,
#    '2018, Mar 07': None,
#    '2018, Mar 08': None,
#    '2018, Mar 13': None,
#    '2018, Mar 20': None,
#    '2018, Mar 21': None,
#    '2018, Mar 26': None,
#    '2018, Mar 29': None,
#    '2018, May 07': None,
#    '2018, Nov 19': None,
#    '2018, Nov 21': None,
#    '2018, Nov 29': None,
#    '2018, Nov 30': None,
#    '2018, Oct 02': None,
#    '2018, Oct 23': None,
#    '2018, Oct 30': None,
#    '2018, Sep 04': None,
#    '2018, Sep 07': None,
#    '2018, Sep 10': None,
#    '2018, Sep 18': None,
#    '2018, Sep 19': None,
#    '2018, Sep 20': None,
#    '2018, Sep 21': None,
#    '2018, Sep 25': None,
#    '20181001_Risk-Assessment_CI-on-behalf-GmbH_all.xlsx': None,
#    '2019, Apr 05': None,
#    '2019, Apr 08': None,
#    '2019, Apr 10': None,
#    '2019, Apr 12': None,
#    '2019, Apr 15': None,
#    '2019, Apr 16': None,
#    '2019, Apr 18': None,
#    '2019, Apr 23': None,
#    '2019, Apr 24': None,
#    '2019, Apr 26': None,
#    '2019, Aug 01': None,
#    '2019, Aug 02': None,
#    '2019, Aug 13': None,
#    '2019, Aug 14': None,
#    '2019, Aug 15': None,
#    '2019, Aug 20': None,
#    '2019, Dec 06': None,
#    '2019, Dec 09': None,
#    '2019, Dec 11': None,
#    '2019, Dec 16': None,
#    '2019, Feb 18': None,
#    '2019, Jan 07': None,
#    '2019, Jan 08': None,
#    '2019, Jan 10': None,
#    '2019, Jan 11': None,
#    '2019, Jan 24': None,
#    '2019, Jan 25': None,
#    '2019, Jan 28': None,
#    '2019, Jan 29': None,
#    '2019, Jul 02': None,
#    '2019, Jul 09': None,
#    '2019, Jul 11': None,
#    '2019, Jul 15': None,
#    '2019, Jul 17': None,
#    '2019, Jul 25': None,
#    '2019, Jun 07': None,
#    '2019, Jun 11': None,
#    '2019, Jun 19': None,
#    '2019, Mar 12': None,
#    '2019, Mar 18': None,
#    '2019, Mar 25': None,
#    '2019, Mar 26': None,
#    '2019, Mar 27': None,
#    '2019, Mar 28': None,
#    '2019, May 13': None,
#    '2019, May 14': None,
#    '2019, May 23': None,
#    '2019, Nov 06': None,
#    '2019, Nov 08': None,
#    '2019, Nov 11': None,
#    '2019, Nov 12': None,
#    '2019, Nov 20': None,
#    '2019, Nov 27': None,
#    '2019, Nov 28': None,
#    '2019, Nov 29': None,
#    '2019, Oct 08': None,
#    '2019, Oct 09': None,
#    '2019, Oct 11': None,
#    '2019, Oct 15': None,
#    '2019, Oct 21': None,
#    '2019, Oct 24': None,
#    '2019, Oct 29': None,
#    '2019, Sep 04': None,
#    '2019, Sep 10': None,
#    '2019, Sep 16': None,
#    '2019, Sep 18': None,
#    '2019, Sep 23': None,
#    '2019, Sep 25': None,
#    '2019, Sep 27': None,
#    '2019, Sep 30': None,
#    '2019-04-11Einordnung ARA Fragen.xlsx': None,
#    '2019-12': None,
#    '2020, Apr 03': None,
#    '2020, Apr 06': None,
#    '2020, Apr 07': None,
#    '2020, Apr 09': None,
#    '2020, Apr 15': None,
#    '2020, Apr 22': None,
#    '2020, Apr 27': None,
#    '2020, Apr 30': None,
#    '2020, Aug 13': None,
#    '2020, Aug 14': None,
#    '2020, Aug 20': None,
#    '2020, Aug 23': None,
#    '2020, Aug 24': None,
#    '2020, Aug 28': None,
#    '2020, Dec 02': None,
#    '2020, Dec 03': None,
#    '2020, Dec 04': None,
#    '2020, Dec 09': None,
#    '2020, Dec 10': None,
#    '2020, Dec 30': None,
#    '2020, Feb 03': None,
#    '2020, Feb 04': None,
#    '2020, Feb 05': None,
#    '2020, Feb 11': None,
#    '2020, Feb 13': None,
#    '2020, Feb 18': None,
#    '2020, Feb 21': None,
#    '2020, Feb 24': None,
#    '2020, Feb 25': None,
#    '2020, Jan 08': None,
#    '2020, Jan 09': None,
#    '2020, Jan 15': None,
#    '2020, Jan 17': None,
#    '2020, Jan 23': None,
#    '2020, Jan 28': None,
#    '2020, Jul 01': None,
#    '2020, Jul 06': None,
#    '2020, Jul 16': None,
#    '2020, Jul 23': None,
#    '2020, Jun 02': None,
#    '2020, Jun 03': None,
#    '2020, Jun 19': None,
#    '2020, Jun 24': None,
#    '2020, Jun 30': None,
#    '2020, Mar 03': None,
#    '2020, Mar 05': None,
#    '2020, Mar 06': None,
#    '2020, Mar 09': None,
#    '2020, Mar 10': None,
#    '2020, Mar 12': None,
#    '2020, Mar 17': None,
#    '2020, Mar 23': None,
#    '2020, Mar 24': None,
#    '2020, Mar 25': None,
#    '2020, Mar 30': None,
#    '2020, Mar 31': None,
#    '2020, May 08': None,
#    '2020, May 13': None,
#    '2020, Nov 03': None,
#    '2020, Nov 12': None,
#    '2020, Nov 19': None,
#    '2020, Nov 21': None,
#    '2020, Nov 24': None,
#    '2020, Nov 25': None,
#    '2020, Nov 26': None,
#    '2020, Oct 08': None,
#    '2020, Oct 12': None,
#    '2020, Oct 22': None,
#    '2020, Oct 26': None,
#    '2020, Oct 27': None,
#    '2020, Oct 28': None,
#    '2020, Sep 01': None,
#    '2020, Sep 03': None,
#    '2020, Sep 04': None,
#    '2020, Sep 07': None,
#    '2020, Sep 08': None,
#    '2020, Sep 25': None,
#    '2020, Sep 28': None,
#    '2020, Sep 29': None,
#    '2020, Sep 30': None,
#    '2020-10-21-Securing the SAP Fileshare_v5.pptx': None,
#    '2020_10_Automic_AUT_Roadmap_bosch.pdf': None,
#    '2020_Auswertung_Lasttests_V5.xlsx': None,
#    '2021 O7Risk_Analysis.pdf': None,
#    '2021 Operation Manual.pdf': None,
#    '2021, Apr 01': None,
#    '2021, Apr 07': None,
#    '2021, Apr 13': None,
#    '2021, Apr 19': None,
#    '2021, Apr 21': None,
#    '2021, Apr 27': None,
#    '2021, Apr 30': None,
#    '2021, Aug 04': None,
#    '2021, Aug 13': None,
#    '2021, Aug 23': None,
#    '2021, Aug 24': None,
#    '2021, Aug 27': None,
#    '2021, Aug 31': None,
#    '2021, Dec 01': None,
#    '2021, Dec 09': None,
#    '2021, Dec 17': None,
#    '2021, Feb 01': None,
#    '2021, Feb 02': None,
#    '2021, Feb 03': None,
#    '2021, Feb 05': None,
#    '2021, Feb 08': None,
#    '2021, Feb 09': None,
#    '2021, Feb 10': None,
#    '2021, Feb 11': None,
#    '2021, Feb 12': None,
#    '2021, Feb 16': None,
#    '2021, Feb 17': None,
#    '2021, Feb 22': None,
#    '2021, Feb 23': None,
#    '2021, Feb 24': None,
#    '2021, Feb 25': None,
#    '2021, Feb 26': None,
#    '2021, Jan 07': None,
#    '2021, Jan 13': None,
#    '2021, Jan 21': None,
#    '2021, Jan 25': None,
#    '2021, Jan 26': None,
#    '2021, Jul 01': None,
#    '2021, Jul 14': None,
#    '2021, Jul 16': None,
#    '2021, Jul 19': None,
#    '2021, Jul 20': None,
#    '2021, Jul 27': None,
#    '2021, Jun 01': None,
#    '2021, Jun 07': None,
#    '2021, Jun 08': None,
#    '2021, Jun 10': None,
#    '2021, Jun 11': None,
#    '2021, Jun 15': None,
#    '2021, Jun 18': None,
#    '2021, Jun 21': None,
#    '2021, Jun 28': None,
#    '2021, Jun 30': None,
#    '2021, Mar 01': None,
#    '2021, Mar 02': None,
#    '2021, Mar 03': None,
#    '2021, Mar 04': None,
#    '2021, Mar 05': None,
#    '2021, Mar 12': None,
#    '2021, Mar 15': None,
#    '2021, Mar 19': None,
#    '2021, Mar 22': None,
#    '2021, Mar 23': None,
#    '2021, Mar 26': None,
#    '2021, Mar 29': None,
#    '2021, Mar 30': None,
#    '2021, May 05': None,
#    '2021, May 10': None,
#    '2021, May 25': None,
#    '2021, May 26': None,
#    '2021, May 27': None,
#    '2021, Nov 03': None,
#    '2021, Nov 23': None,
#    '2021, Nov 29': None,
#    '2021, Oct 01': None,
#    '2021, Oct 11': None,
#    '2021, Oct 25': None,
#    '2021, Sep 01': None,
#    '2021, Sep 17': None,
#    '2021, Sep 21': None,
#    '2021, Sep 29': None,
#    '2021-08-13-FT-Vulnerability.pptx': None,
#    '20210928_Selbstcheck_POD³ 1.1.xlsm': None,
#    '20210928_Selbstcheck_TCT - Nexeed Insertion.xlsm': None,
#    '20210928_Selbstcheck_TCT Adapter.xlsm': None,
#    '2021_ARA_Approval_Control.pdf': None,
#    '2022, Apr 01': None,
#    '2022, Apr 11': None,
#    '2022, Apr 13': None,
#    '2022, Apr 14': None,
#    '2022, Apr 19': None,
#    '2022, Apr 25': None,
#    '2022, Apr 28': None,
#    '2022, Apr 29': None,
#    '2022, Aug 01': None,
#    '2022, Aug 11': None,
#    '2022, Aug 16': None,
#    '2022, Aug 17': None,
#    '2022, Aug 19': None,
#    '2022, Aug 22': None,
#    '2022, Aug 23': None,
#    '2022, Aug 24': None,
#    '2022, Aug 26': None,
#    '2022, Aug 29': None,
#    '2022, Aug 30': None,
#    '2022, Dec 01': None,
#    '2022, Dec 05': None,
#    '2022, Dec 06': None,
#    '2022, Dec 07': None,
#    '2022, Dec 13': None,
#    '2022, Dec 20': None,
#    '2022, Dec 22': None,
#    '2022, Dec 29': None,
#    '2022, Feb 03': None,
#    '2022, Feb 04': None,
#    '2022, Feb 08': None,
#    '2022, Feb 09': None,
#    '2022, Feb 11': None,
#    '2022, Feb 16': None,
#    '2022, Feb 18': None,
#    '2022, Feb 28': None,
#    '2022, Jan 04': None,
#    '2022, Jan 05': None,
#    '2022, Jan 07': None,
#    '2022, Jan 17': None,
#    '2022, Jan 18': None,
#    '2022, Jan 19': None,
#    '2022, Jan 25': None,
#    '2022, Jan 27': None,
#    '2022, Jul 06': None,
#    '2022, Jul 12': None,
#    '2022, Jul 13': None,
#    '2022, Jul 14': None,
#    '2022, Jul 15': None,
#    '2022, Jul 19': None,
#    '2022, Jul 21': None,
#    '2022, Jul 26': None,
#    '2022, Jul 28': None,
#    '2022, Jun 01': None,
#    '2022, Jun 02': None,
#    '2022, Jun 03': None,
#    '2022, Jun 08': None,
#    '2022, Jun 09': None,
#    '2022, Jun 10': None,
#    '2022, Jun 15': None,
#    '2022, Jun 17': None,
#    '2022, Jun 21': None,
#    '2022, Jun 23': None,
#    '2022, Jun 24': None,
#    '2022, Jun 27': None,
#    '2022, Jun 28': None,
#    '2022, Jun 29': None,
#    '2022, Mar 02': None,
#    '2022, Mar 03': None,
#    '2022, Mar 04': None,
#    '2022, Mar 07': None,
#    '2022, Mar 09': None,
#    '2022, Mar 10': None,
#    '2022, Mar 17': None,
#    '2022, Mar 21': None,
#    '2022, Mar 22': None,
#    '2022, Mar 23': None,
#    '2022, Mar 24': None,
#    '2022, Mar 25': None,
#    '2022, Mar 28': None,
#    '2022, Mar 30': None,
#    '2022, Mar 31': None,
#    '2022, May 06': None,
#    '2022, May 09': None,
#    '2022, May 11': None,
#    '2022, May 18': None,
#    '2022, May 20': None,
#    '2022, May 24': None,
#    '2022, May 26': None,
#    '2022, May 29': None,
#    '2022, May 30': None,
#    '2022, Nov 03': None,
#    '2022, Nov 04': None,
#    '2022, Nov 11': None,
#    '2022, Nov 17': None,
#    '2022, Nov 22': None,
#    '2022, Nov 29': None,
#    '2022, Oct 04': None,
#    '2022, Oct 05': None,
#    '2022, Oct 12': None,
#    '2022, Oct 13': None,
#    '2022, Oct 14': None,
#    '2022, Oct 17': None,
#    '2022, Oct 19': None,
#    '2022, Oct 20': None,
#    '2022, Oct 24': None,
#    '2022, Oct 25': None,
#    '2022, Oct 31': None,
#    '2022, Sep 01': None,
#    '2022, Sep 02': None,
#    '2022, Sep 06': None,
#    '2022, Sep 09': None,
#    '2022, Sep 15': None,
#    '2022, Sep 19': None,
#    '2022, Sep 20': None,
#    '2022, Sep 22': None,
#    '2022, Sep 26': None,
#    '2022, Sep 28': None,
#    '2022, Sep 29': None,
#    '2022, Sep 30': None,
#    '2023, Apr 03': None,
#    '2023, Apr 05': None,
#    '2023, Apr 10': None,
#    '2023, Apr 11': None,
#    '2023, Apr 13': None,
#    '2023, Apr 14': None,
#    '2023, Apr 15': None,
#    '2023, Apr 18': None,
#    '2023, Apr 20': None,
#    '2023, Apr 24': None,
#    '2023, Apr 26': None,
#    '2023, Apr 27': None,
#    '2023, Apr 28': None,
#    '2023, Aug 02': None,
#    '2023, Aug 03': None,
#    '2023, Aug 08': None,
#    '2023, Aug 09': None,
#    '2023, Aug 11': None,
#    '2023, Aug 15': None,
#    '2023, Aug 16': None,
#    '2023, Aug 17': None,
#    '2023, Aug 24': None,
#    '2023, Aug 25': None,
#    '2023, Aug 28': None,
#    '2023, Aug 30': None,
#    '2023, Aug 31': None,
#    '2023, Dec 01': None,
#    '2023, Dec 04': None,
#    '2023, Dec 05': None,
#    '2023, Dec 06': None,
#    '2023, Dec 11': None,
#    '2023, Dec 13': None,
#    '2023, Dec 14': None,
#    '2023, Dec 15': None,
#    '2023, Dec 19': None,
#    '2023, Dec 20': None,
#    '2023, Dec 21': None,
#    '2023, Feb 01': None,
#    '2023, Feb 02': None,
#    '2023, Feb 06': None,
#    '2023, Feb 07': None,
#    '2023, Feb 08': None,
#    '2023, Feb 09': None,
#    '2023, Feb 10': None,
#    '2023, Feb 15': None,
#    '2023, Feb 21': None,
#    '2023, Feb 22': None,
#    '2023, Feb 24': None,
#    '2023, Feb 27': None,
#    '2023, Feb 28': None,
#    '2023, Jan 02': None,
#    '2023, Jan 03': None,
#    '2023, Jan 04': None,
#    '2023, Jan 05': None,
#    '2023, Jan 06': None,
#    '2023, Jan 09': None,
#    '2023, Jan 10': None,
#    '2023, Jan 11': None,
#    '2023, Jan 12': None,
#    '2023, Jan 13': None,
#    '2023, Jan 16': None,
#    '2023, Jan 17': None,
#    '2023, Jan 18': None,
#    '2023, Jan 20': None,
#    '2023, Jan 23': None,
#    '2023, Jan 26': None,
#    '2023, Jan 27': None,
#    '2023, Jan 30': None,
#    '2023, Jul 03': None,
#    '2023, Jul 04': None,
#    '2023, Jul 05': None,
#    '2023, Jul 06': None,
#    '2023, Jul 10': None,
#    '2023, Jul 13': None,
#    '2023, Jul 19': None,
#    '2023, Jul 25': None,
#    '2023, Jul 26': None,
#    '2023, Jul 27': None,
#    '2023, Jul 28': None,
#    '2023, Jun 02': None,
#    '2023, Jun 05': None,
#    '2023, Jun 06': None,
#    '2023, Jun 08': None,
#    '2023, Jun 09': None,
#    '2023, Jun 12': None,
#    '2023, Jun 13': None,
#    '2023, Jun 14': None,
#    '2023, Jun 15': None,
#    '2023, Jun 20': None,
#    '2023, Jun 22': None,
#    '2023, Jun 23': None,
#    '2023, Jun 26': None,
#    '2023, Jun 27': None,
#    '2023, Jun 28': None,
#    '2023, Jun 29': None,
#    '2023, Jun 30': None,
#    '2023, Mar 01': None,
#    '2023, Mar 02': None,
#    '2023, Mar 03': None,
#    '2023, Mar 10': None,
#    '2023, Mar 13': None,
#    '2023, Mar 14': None,
#    '2023, Mar 15': None,
#    '2023, Mar 17': None,
#    '2023, Mar 21': None,
#    '2023, Mar 23': None,
#    '2023, Mar 27': None,
#    '2023, Mar 28': None,
#    '2023, Mar 30': None,
#    '2023, Mar 31': None,
#    '2023, May 03': None,
#    '2023, May 05': None,
#    '2023, May 09': None,
#    '2023, May 10': None,
#    '2023, May 11': None,
#    '2023, May 12': None,
#    '2023, May 15': None,
#    '2023, May 16': None,
#    '2023, May 17': None,
#    '2023, May 24': None,
#    '2023, May 25': None,
#    '2023, May 30': None,
#    '2023, May 31': None,
#    '2023, Nov 01': None,
#    '2023, Nov 02': None,
#    '2023, Nov 03': None,
#    '2023, Nov 04': None,
#    '2023, Nov 06': None,
#    '2023, Nov 07': None,
#    '2023, Nov 08': None,
#    '2023, Nov 09': None,
#    '2023, Nov 10': None,
#    '2023, Nov 13': None,
#    '2023, Nov 15': None,
#    '2023, Nov 16': None,
#    '2023, Nov 17': None,
#    '2023, Nov 20': None,
#    '2023, Nov 22': None,
#    '2023, Nov 23': None,
#    '2023, Nov 27': None,
#    '2023, Nov 28': None,
#    '2023, Nov 30': None,
#    '2023, Oct 05': None,
#    '2023, Oct 06': None,
#    '2023, Oct 09': None,
#    '2023, Oct 10': None,
#    '2023, Oct 17': None,
#    '2023, Oct 18': None,
#    '2023, Oct 19': None,
#    '2023, Oct 24': None,
#    '2023, Oct 25': None,
#    '2023, Oct 31': None,
#    '2023, Sep 01': None,
#    '2023, Sep 03': None,
#    '2023, Sep 06': None,
#    '2023, Sep 08': None,
#    '2023, Sep 12': None,
#    '2023, Sep 14': None,
#    '2023, Sep 15': None,
#    '2023, Sep 18': None,
#    '2023, Sep 20': None,
#    '2023, Sep 21': None,
#    '2023, Sep 22': None,
#    '2023, Sep 26': None,
#    '2023, Sep 27': None,
#    '2023, Sep 28': None,
#    '2023-09-21 Flowable Sprint 1 (Review)': None,
#    '2023-10-05 Flowable Sprint 2': None,
#    '2023-10-19 Flowable Sprint 3': None,
#    '2023-11-02 Flowable Sprint 4': None,
#    '2023-11-16 Flowable Sprint 5': None,
#    '2023-11-30 Flowable Sprint 6': None,
#    '2023-12-14 Flowable Sprint 7 🎄': None,
#    '20231019_OperatorSelfChec_ASP.pdf': None,
#    '20231019_OperatorsSelfCheck_AE_INFO_APP (1).pdf': None,
#    '20231214 - Flowable ISDS Checklist CD-02900-007_ANH_Z_EN_2022-04-27.xlsm': None,
#    '20232012_Flowable_AG_Pentest_Report.zip': None,
#    '2023_11_C-AU-Audit_BD-PO-Overview.pptx': None,
#    '2023_UC4_ARA_OperatorSelfCheck.pdf': None,
#    '2024, Apr 02': None,
#    '2024, Apr 03': None,
#    '2024, Apr 04': None,
#    '2024, Apr 05': None,
#    '2024, Apr 07': None,
#    '2024, Apr 08': None,
#    '2024, Apr 10': None,
#    '2024, Apr 11': None,
#    '2024, Apr 12': None,
#    '2024, Apr 15': None,
#    '2024, Apr 16': None,
#    '2024, Apr 17': None,
#    ...},
#   'title': '[Flowable Requirements Backlog](https://inside-docupedia.bosch.com/confluence/display/GWA/Flowable+Requirements+Backlog)'}]

# %%
from unsloth.chat_templates import get_chat_template

tokenizer = get_chat_template(
    tokenizer,
    chat_template = "phi-4",
)

def formatting_prompts_func(examples):
    convos = examples["conversations"]
    texts = [
        tokenizer.apply_chat_template(
            convo, tokenize = False, add_generation_prompt = False
        )
        for convo in convos
    ]
    return { "text" : texts, }
pass

from datasets import load_dataset
dataset = load_dataset("mlabonne/FineTome-100k", split = "train")

# %%
dataset
# Out:
# Dataset({
#     features: ['conversations', 'source', 'score', 'text'],
#     num_rows: 100000
# })

# %% [markdown]
# We now use `standardize_sharegpt` to convert ShareGPT style datasets into HuggingFace's generic format. This changes the dataset from looking like:
# ```
# {"from": "system", "value": "You are an assistant"}
# {"from": "human", "value": "What is 2+2?"}
# {"from": "gpt", "value": "It's 4."}
# ```
# to
# ```
# {"role": "system", "content": "You are an assistant"}
# {"role": "user", "content": "What is 2+2?"}
# {"role": "assistant", "content": "It's 4."}
# ```

# %%
from unsloth.chat_templates import standardize_sharegpt

dataset = standardize_sharegpt(dataset)
dataset = dataset.map(
    formatting_prompts_func,
    batched=True,
)
# Out:
# Standardizing format:   0%|          | 0/100000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/100000 [00:00<?, ? examples/s]

# %% [markdown]
# We look at how the conversations are structured for item 5:

# %%
dataset[5]["conversations"]
# Out:
# [{'content': 'How do astronomers determine the original wavelength of light emitted by a celestial body at rest, which is necessary for measuring its speed using the Doppler effect?',
#   'role': 'user'},
#  {'content': 'Astronomers make use of the unique spectral fingerprints of elements found in stars. These elements emit and absorb light at specific, known wavelengths, forming an absorption spectrum. By analyzing the light received from distant stars and comparing it to the laboratory-measured spectra of these elements, astronomers can identify the shifts in these wavelengths due to the Doppler effect. The observed shift tells them the extent to which the light has been redshifted or blueshifted, thereby allowing them to calculate the speed of the star along the line of sight relative to Earth.',
#   'role': 'assistant'}]

# %% [markdown]
# And we see how the chat template transformed these conversations.

# %%
dataset[5]["text"]
# Out:
# '<|im_start|>user<|im_sep|>How do astronomers determine the original wavelength of light emitted by a celestial body at rest, which is necessary for measuring its speed using the Doppler effect?<|im_end|><|im_start|>assistant<|im_sep|>Astronomers make use of the unique spectral fingerprints of elements found in stars. These elements emit and absorb light at specific, known wavelengths, forming an absorption spectrum. By analyzing the light received from distant stars and comparing it to the laboratory-measured spectra of these elements, astronomers can identify the shifts in these wavelengths due to the Doppler effect. The observed shift tells them the extent to which the light has been redshifted or blueshifted, thereby allowing them to calculate the speed of the star along the line of sight relative to Earth.<|im_end|>'

# %%
string = UC4_dataset[5]["combined_text"]

# %%
string = "<|im_start|>assistant<|im_sep|>"+string+"<|im_end|>"

# %%
print(string)
# Out:
# <|im_start|>assistant<|im_sep|>1. [Pages](https://inside-docupedia.bosch.com/confluence/collector/pages.action?key=GWA&src=breadcrumbs-collector)
# 2. [Home](https://inside-docupedia.bosch.com/confluence/display/GWA/Home?src=breadcrumbs-expanded)
# 3. [ALPS Team Area](https://inside-docupedia.bosch.com/confluence/display/GWA/ALPS+Team+Area?src=breadcrumbs-expanded)
# 4. [TO_BE_DELETED: Flowable](https://inside-docupedia.bosch.com/confluence/display/GWA/TO_BE_DELETED%3A+Flowable?src=breadcrumbs-parent)
#
# # [Flowable Cyber Security](https://inside-docupedia.bosch.com/confluence/display/GWA/Flowable+Cyber+Security)
#
# * Created by  [Ranjan Rakesh (MS/ECL5)](https://inside-docupedia.bosch.com/confluence/display/~NFJ1KOR) on [2023, Dec 04](https://inside-docupedia.bosch.com/confluence/pages/viewpreviousversions.action?pageId=3723661172 "Show changes")
#
#   Current Version V 1
# [Page Info](# "Space Info")<|im_end|>

# %%
UC4_dataset[5]["combined_text"] = string

# %%
UC4_dataset[5]["combined_text"]
# Out:
# '1. [Pages](https://inside-docupedia.bosch.com/confluence/collector/pages.action?key=GWA&src=breadcrumbs-collector)\n2. [Home](https://inside-docupedia.bosch.com/confluence/display/GWA/Home?src=breadcrumbs-expanded)\n3. [ALPS Team Area](https://inside-docupedia.bosch.com/confluence/display/GWA/ALPS+Team+Area?src=breadcrumbs-expanded)\n4. [TO_BE_DELETED: Flowable](https://inside-docupedia.bosch.com/confluence/display/GWA/TO_BE_DELETED%3A+Flowable?src=breadcrumbs-parent)\n\n# [Flowable Cyber Security](https://inside-docupedia.bosch.com/confluence/display/GWA/Flowable+Cyber+Security)\n\n* Created by  [Ranjan Rakesh (MS/ECL5)](https://inside-docupedia.bosch.com/confluence/display/~NFJ1KOR) on [2023, Dec 04](https://inside-docupedia.bosch.com/confluence/pages/viewpreviousversions.action?pageId=3723661172 "Show changes")\n  \n  Current Version V 1\n[Page Info](# "Space Info")'

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface TRL's `SFTTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`. We also support TRL's `DPOTrainer`!

# %%
from trl import SFTTrainer
from transformers import TrainingArguments, DataCollatorForSeq2Seq
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    data_collator = DataCollatorForSeq2Seq(tokenizer = tokenizer),
    dataset_num_proc = 2,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        # num_train_epochs = 1, # Set this for 1 full training run.
        max_steps = 30,
        learning_rate = 2e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "none", # Use this for WandB etc
    ),
)
# Out:
# Map (num_proc=2):   0%|          | 0/100000 [00:00<?, ? examples/s]

# %% [markdown]
# We also use Unsloth's `train_on_completions` method to only train on the assistant outputs and ignore the loss on the user's inputs.

# %%
from unsloth.chat_templates import train_on_responses_only

trainer = train_on_responses_only(
    trainer,
    instruction_part="<|im_start|>user<|im_sep|>",
    response_part="<|im_start|>assistant<|im_sep|>",
)
# Out:
# Map:   0%|          | 0/100000 [00:00<?, ? examples/s]

# %% [markdown]
# We verify masking is actually done:

# %%
tokenizer.decode(trainer.train_dataset[5]["input_ids"])
# Out:
# '<|im_start|>user<|im_sep|>How do astronomers determine the original wavelength of light emitted by a celestial body at rest, which is necessary for measuring its speed using the Doppler effect?<|im_end|><|im_start|>assistant<|im_sep|>Astronomers make use of the unique spectral fingerprints of elements found in stars. These elements emit and absorb light at specific, known wavelengths, forming an absorption spectrum. By analyzing the light received from distant stars and comparing it to the laboratory-measured spectra of these elements, astronomers can identify the shifts in these wavelengths due to the Doppler effect. The observed shift tells them the extent to which the light has been redshifted or blueshifted, thereby allowing them to calculate the speed of the star along the line of sight relative to Earth.<|im_end|>'

# %%
space = tokenizer(" ", add_special_tokens = False).input_ids[0]
tokenizer.decode([space if x == -100 else x for x in trainer.train_dataset[5]["labels"]])
# Out:
# '                                     Astronomers make use of the unique spectral fingerprints of elements found in stars. These elements emit and absorb light at specific, known wavelengths, forming an absorption spectrum. By analyzing the light received from distant stars and comparing it to the laboratory-measured spectra of these elements, astronomers can identify the shifts in these wavelengths due to the Doppler effect. The observed shift tells them the extent to which the light has been redshifted or blueshifted, thereby allowing them to calculate the speed of the star along the line of sight relative to Earth.<|im_end|>'

# %% [markdown]
# We can see the System and Instruction prompts are successfully masked!

# %%
# @title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.748 GB.
# 10.043 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 100,000 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 30
#  "-____-"     Number of trainable parameters = 65,536,000
#     <div>
#
#       <progress value='30' max='30' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [30/30 15:11, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.746700</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.660800</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.035700</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.767600</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.693200</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.818100</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.464400</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.831800</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.600800</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.525800</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.700200</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.760500</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.774900</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.452600</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.634000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.395300</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.783800</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.656200</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.605400</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.770700</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.732600</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.535400</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.910900</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.721200</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.500100</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.590200</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.658900</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.657500</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.698500</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.770000</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# @title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory / max_memory * 100, 3)
lora_percentage = round(used_memory_for_lora / max_memory * 100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(
    f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training."
)
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 959.8611 seconds used for training.
# 16.0 minutes used for training.
# Peak reserved memory = 12.361 GB.
# Peak reserved memory for training = 2.318 GB.
# Peak reserved memory % of max memory = 83.815 %.
# Peak reserved memory for training % of max memory = 15.717 %.

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model! You can change the instruction and input - leave the output blank!
#
# **[NEW] Try 2x faster inference in a free Colab for Llama-3.1 8b Instruct [here](https://colab.research.google.com/drive/1T-YBVfnphoVc8E2E854qF3jdia2Ll2W2?usp=sharing)**
#
# We use `min_p = 0.1` and `temperature = 1.5`.

# %%
from unsloth.chat_templates import get_chat_template

tokenizer = get_chat_template(
    tokenizer,
    chat_template = "phi-4",
)
FastLanguageModel.for_inference(model) # Enable native 2x faster inference

messages = [
    {"role": "user", "content": "Continue the fibonnaci sequence: 1, 1, 2, 3, 5, 8,"},
]
inputs = tokenizer.apply_chat_template(
    messages,
    tokenize = True,
    add_generation_prompt = True, # Must add for generation
    return_tensors = "pt",
).to("cuda")

outputs = model.generate(
    input_ids = inputs, max_new_tokens = 64, use_cache = True, temperature = 1.5, min_p = 0.1
)
tokenizer.batch_decode(outputs)
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ['<|im_start|>user<|im_sep|>Continue the fibonnaci sequence: 1, 1, 2, 3, 5, 8,<|im_end|><|im_start|>assistant<|im_sep|>The next number in the Fibonacci sequence is 13. The Fibonacci sequence is a series of numbers in which each number is the sum of the two preceding ones, usually starting with 0 and 1. In this case, the sequence starts with 1 and 1, and each subsequent number is the sum of the']

# %% [markdown]
#  You can also use a `TextStreamer` for continuous inference - so you can see the generation token by token, instead of waiting the whole time!

# %%
FastLanguageModel.for_inference(model) # Enable native 2x faster inference

messages = [
    {"role": "user", "content": "Continue the fibonnaci sequence: 1, 1, 2, 3, 5, 8,"},
]
inputs = tokenizer.apply_chat_template(
    messages,
    tokenize = True,
    add_generation_prompt = True, # Must add for generation
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer, skip_prompt = True)
_ = model.generate(
    input_ids = inputs, streamer = text_streamer, max_new_tokens = 128,
    use_cache = True, temperature = 1.5, min_p = 0.1
)
# Out:
# The next number in the Fibonacci sequence is 13. The Fibonacci sequence is a series of numbers in which each number is the sum of the two preceding ones, usually starting with 0 and 1. In this case, the sequence starts with 1 and 1, and each subsequent number is the sum of the two preceding numbers. So, the next number after 8 is 13, which is the sum of 5 and 8.<|im_end|>

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
model.save_pretrained("lora_model")  # Local saving
tokenizer.save_pretrained("lora_model")
# model.push_to_hub("your_name/lora_model", token = "...") # Online saving
# tokenizer.push_to_hub("your_name/lora_model", token = "...") # Online saving
# Out:
# ('lora_model/tokenizer_config.json',
#  'lora_model/special_tokens_map.json',
#  'lora_model/vocab.json',
#  'lora_model/merges.txt',
#  'lora_model/added_tokens.json',
#  'lora_model/tokenizer.json')

# %% [markdown]
# Now if you want to load the LoRA adapters we just saved for inference, set `False` to `True`:

# %%
if False:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length = max_seq_length,
        dtype = dtype,
        load_in_4bit = load_in_4bit,
    )
    FastLanguageModel.for_inference(model) # Enable native 2x faster inference

messages = [
    {"role": "user", "content": "Describe a tall tower in the capital of France."},
]
inputs = tokenizer.apply_chat_template(
    messages,
    tokenize = True,
    add_generation_prompt = True, # Must add for generation
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer, skip_prompt = True)
_ = model.generate(
    input_ids = inputs, streamer = text_streamer, max_new_tokens = 128,
    use_cache = True, temperature = 1.5, min_p = 0.1
)
# Out:
# The Eiffel Tower is a tall tower located in the capital of France, Paris. It stands at a height of 324 meters (1,063 feet) and was completed in 1889. The tower was designed by Gustave Eiffel and his team for the 1889 Exposition Universelle (World's Fair) to celebrate the 100th anniversary of the French Revolution. It is made of wrought iron and consists of three levels that are accessible to visitors. The Eiffel Tower is one of the most recognizable landmarks in the world and attracts millions of tourists each year.<|im_end|>

# %% [markdown]
# You can also use Hugging Face's `AutoModelForPeftCausalLM`. Only use this if you do not have `unsloth` installed. It can be hopelessly slow, since `4bit` model downloading is not supported, and Unsloth's **inference is 2x faster**.

# %%
if False:
    # I highly do NOT suggest - use Unsloth if possible
    from peft import AutoPeftModelForCausalLM
    from transformers import AutoTokenizer

    model = AutoPeftModelForCausalLM.from_pretrained(
        "lora_model",  # YOUR MODEL YOU USED FOR TRAINING
        load_in_4bit=load_in_4bit,
    )
    tokenizer = AutoTokenizer.from_pretrained("lora_model")

# %% [markdown]
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
from google.colab import userdata
# Merge to 16bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_16bit", token = "")

# Merge to 4bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_4bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_4bit", token = "")

# Just LoRA adapters
if False: model.save_pretrained_merged("model", tokenizer, save_method = "lora",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "lora", token = "")

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list in our [Docs](https://docs.unsloth.ai/basics/saving-and-using-models/saving-to-gguf)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.
#
# [**NEW**] To finetune and auto export to Ollama, try our [Ollama notebook](https://colab.research.google.com/drive/1WZDi7APtQ9VsvOrQSSC5DDtxq159j8iZ?usp=sharing)

# %%
# Save to 8bit Q8_0
if False: model.save_pretrained_gguf("model", tokenizer,)
# Remember to go to https://huggingface.co/settings/tokens for a token!
# And change hf to your username!
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")

# Save to 16bit GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

# Save to q4_k_m GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")

# Save to multiple GGUF options - much faster if you want multiple!
if False:
    model.push_to_hub_gguf(
        "hf/model", # Change hf to your username!
        tokenizer,
        quantization_method = ["q4_k_m", "q8_0", "q5_k_m",],
        token = "", # Get a token at https://huggingface.co/settings/tokens
    )

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in llama.cpp or a UI based system like Jan or Open WebUI. You can install Jan [here](https://github.com/janhq/jan) and Open WebUI [here](https://github.com/open-webui/open-webui)
#
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Llama 3.2 Conversational notebook. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(1B_and_3B)-Conversational.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>
